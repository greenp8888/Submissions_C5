# %% [markdown]
# # Academic Papers RAG System Tutorial
#
# This notebook demonstrates how to build a complete RAG (Retrieval-Augmented Generation) system for academic research papers using LlamaIndex. We'll build it step by step with independent functions that you can run and understand individually.
#
# ## What is RAG?
#
# RAG combines the power of:
# - **Retrieval**: Finding relevant documents from a knowledge base
# - **Augmented Generation**: Using retrieved context to generate informed responses
#
# ## System Components
#
# Our RAG system will include:
# 1. **PDF Processing**: Extract text from academic papers
# 2. **Document Chunking**: Split documents into searchable segments
# 3. **Vector Embeddings**: Convert text to numerical representations
# 4. **Vector Storage**: Store embeddings in LanceDB
# 5. **Semantic Search**: Find relevant content for queries
# 6. **Query Engine**: Generate responses using retrieved context

# %% [markdown]
# ## 🏗️ Storage Architecture: Why StorageContext Matters
#
# This notebook uses LlamaIndex's **StorageContext** approach, which provides significant advantages over simpler vector-only storage methods. Understanding this architecture is crucial for building production-ready RAG systems.
#
# ### 📊 StorageContext vs. Simple Vector Storage
#
# | Component | StorageContext (This Notebook) | Simple Vector Store | Benefits |
# |-----------|-------------------------------|-------------------|----------|
# | **Vector Store** | ✅ LanceDB embeddings | ✅ LanceDB embeddings | Fast similarity search |
# | **Document Store** | ✅ Original documents preserved | ❌ Lost after processing | Full document access |
# | **Index Store** | ✅ Index metadata & structure | ❌ Must rebuild index | Exact reconstruction |
# | **Graph Store** | ✅ Document relationships | ❌ No relationship data | Rich context understanding |
#
# ### 🔄 Persistence & Recovery Capabilities
#
# **With StorageContext (Our Approach):**
# ```python
# # Save complete system state
# index.storage_context.persist(persist_dir="storage/papers_index")
#
# # Perfect restoration - identical behavior
# storage_context = StorageContext.from_defaults(persist_dir="storage/papers_index")
# index = load_index_from_storage(storage_context)
# # 🎯 Exact same results every time!
# ```
#
# **Simple Vector Store Only:**
# ```python
# # Only vectors saved
# vector_store = LanceDBVectorStore(uri="./vectors")
#
# # Must recreate everything from scratch
# index = VectorStoreIndex.from_vector_store(vector_store)
# # ⚠️ May have different behavior, lost metadata
# ```
#
# ### 💡 Key Advantages of StorageContext
#
# 1. **🔄 Perfect Reproducibility**: Identical results across sessions - critical for research and development
# 2. **📦 Complete State Management**: All components preserved, not just vectors
# 3. **⚡ Fast Startup**: No reprocessing needed - load existing index instantly
# 4. **🔍 Rich Metadata**: Document relationships, source tracking, and complex queries
# 5. **🛠️ Development Friendly**: Iterate without rebuilding entire system
# 6. **🎯 Enterprise Ready**: Robust persistence for production deployments
#
# ### 📈 Storage Footprint Example
#
# For 1000 academic papers (~500MB original PDFs):
#
# **StorageContext Storage:**
# ```
# storage/papers_index/
# ├── docstore.json          # 50MB - Original documents
# ├── index_store.json       # 5MB  - Index metadata
# ├── graph_store.json       # 2MB  - Relationships
# └── LanceDB vector files   # 200MB - Embeddings
# Total: ~260MB
# ```
#
# **Benefits**: Complete system restoration, full metadata, relationships preserved
#
# **Simple Vector Storage:**
# ```
# lancedb_data/
# └── vectors.lance          # 200MB - Embeddings only
# Total: ~200MB
# ```
#
# **Limitations**: Must rebuild index, lost metadata, no relationships
#
# ### 🎯 When to Use StorageContext
#
# ✅ **Research & Development** - Need reproducible experiments
# ✅ **Complex Documents** - Rich metadata and relationships matter
# ✅ **Production Systems** - Robust persistence and recovery required
# ✅ **Academic Work** - Full traceability and citation tracking
# ✅ **Multi-user Systems** - Consistent experience across users
#
# ### 🚀 Performance Impact
#
# - **Initial Build**: ~20% slower (stores additional metadata)
# - **Subsequent Loads**: 10x faster (no reprocessing needed)
# - **Query Performance**: Identical to simple vector approach
# - **Storage Space**: ~30% more storage for complete persistence
#
# This tutorial demonstrates the StorageContext approach because it provides the most robust and feature-complete RAG implementation suitable for real-world applications.

# %% [markdown]
# ## 1. Environment Setup and Configuration
#
# First, let's set up our environment and load necessary configurations. We'll use OpenRouter for LLM access and local embeddings (no API keys needed for embeddings).

# %%
# !pip install -r "/content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt"
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (4.13.5)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (2.30.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (2.192.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (2.47.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (5.50.0)
# Requirement already satisfied: gradio_client in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (6.17.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (7.34.0)
# Requirement already satisfied: lancedb in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.30.1)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.14.16)
# Requirement already satisfied: llama-index-vector-stores-lancedb in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.5.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.7.0)
# Requirement already satisfied: llama-index-llms-huggingface-api in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (0.7.0)
# Requirement already satisfied: llama-index-embeddings-openai in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (0.5.2)
# Requirement already satisfied: llama-index-llms-openrouter in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 16)) (0.5.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 17)) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 18)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (2.2.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 20)) (2.28.0)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (20250625)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (2.12.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (5.3.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (2026.3.17)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (3.8.11)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (1.27.1)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (0.31.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.135.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.33.5 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.7.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.11.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (26.0)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.0.22)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (6.0.3)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.24.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.42.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from gradio_client->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 7)) (2025.3.0)
# Requirement already satisfied: websockets<16.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from gradio_client->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 7)) (15.0.1)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (82.0.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (4.9.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (18.1.0)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (4.67.3)
# Requirement already satisfied: lance-namespace>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.5.5)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.16 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.14.19)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.11.1)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.6.26)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.5.6)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.6.1)
# Requirement already satisfied: pylance in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (3.0.1)
# Requirement already satisfied: tantivy in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.25.1)
# Requirement already satisfied: llama-index-llms-openai-like<0.7,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-llms-openrouter->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 16)) (0.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 17)) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 17)) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 17)) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (2025.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 20)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 20)) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (0.60.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2.10.0+cpu)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (0.4.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (5.0.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (1.16.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.24.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.25.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.33.5->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.4.2)
# WARNING: huggingface-hub 1.7.1 does not provide the extra 'inference'
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (5.9.1)
# Requirement already satisfied: lance-namespace-urllib3-client==0.6.1 in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.3.2->lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lance-namespace-urllib3-client==0.6.1->lance-namespace>=0.3.2->lancedb->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (2.5.0)
# Requirement already satisfied: aiohttp<4,>=3.8.6 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (3.13.3)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.17.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (3.6.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (4.9.4)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (9.1.4)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.2.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.1.2)
# Requirement already satisfied: llama-cloud<2,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.6.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.7.1)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (6.9.2)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.5.20)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.20.0->google-api-core->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (3.4.6)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.1.5)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (1.14.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.7.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (7.5.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4,>=3.8.6->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.23.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (3.26.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: griffecli==2.0.2 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: griffelib==2.0.2 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.0.2)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.4.6)

# %%
import os
import time
from pathlib import Path
from typing import Dict, List, Optional, Tuple
from google.colab import userdata

from dotenv import load_dotenv

def setup_environment():
    """
    Setup environment variables and basic configuration.

    Returns:
        bool: Success status
    """
    # Load environment variables from .env file
    load_dotenv()

    # Disable tokenizer warning
    os.environ["TOKENIZERS_PARALLELISM"] = "false"

    # Check for required API key
    try:
        api_key = userdata.get('OPENROUTER_API_KEY')
        if api_key:
            # This line "injects" the secret into the environment
            os.environ["OPENROUTER_API_KEY"] = api_key
            print("✅ OPENROUTER_API_KEY loaded successfully from Colab Secrets")
            return True
        else:
            print("❌ Secret found but value is empty.")
            return False
    except Exception as e:
        print(f"❌ Could not find 'OPENROUTER_API_KEY' in Secrets: {e}")
        print("Make sure the name matches exactly and 'Notebook access' is toggled ON.")
        return False

# Run the setup
success = setup_environment()
if success:
    print("Environment setup complete!")
else:
    print("Environment setup failed!")
# Out:
# ✅ OPENROUTER_API_KEY loaded successfully from Colab Secrets
# Environment setup complete!

# %% [markdown]
# ## 2. Configuration Management
#
# Let's define our system configuration directly in the notebook. This includes model settings, chunk sizes, and other parameters.

# %%
# Configuration parameters for the RAG system
CONFIG = {
    "llm": {
        "model": "gpt-4o",                    # OpenRouter model to use
        "temperature": 0.1                   # Temperature for response generation
    },
    "embeddings": {
        "model": "local:BAAI/bge-small-en-v1.5",  # Local embedding model (no API key needed)
        "chunk_size": 1024,                  # Size of text chunks for processing
        "chunk_overlap": 100                 # Overlap between consecutive chunks
    },
    "vector_store": {
        "type": "lancedb",                   # Vector database type
        "table_name": "academic_papers",     # Table name for storing embeddings
        "path": "storage/papers_vectordb"    # Path to vector database
    },
    "index": {
        "storage_path": "storage/papers_index",  # Path to store complete index
        "similarity_top_k": 5                    # Number of similar chunks to retrieve
    },
    "papers": {
        "folder": "/content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents"      # Path to academic papers folder
    }
}

def get_config(key_path: str, default_value=None):
    """
    Get configuration value using dot notation.

    Args:
        key_path (str): Dot-separated path to the config value (e.g., 'llm.model')
        default_value: Default value if key not found

    Returns:
        Configuration value or default
    """
    keys = key_path.split('.')
    value = CONFIG

    for key in keys:
        if isinstance(value, dict) and key in value:
            value = value[key]
        else:
            return default_value

    return value

# Test configuration access
llm_model = get_config("llm.model")
embedding_model = get_config("embeddings.model")
chunk_size = get_config("embeddings.chunk_size")

print(f"LLM model: {llm_model}")
print(f"Embedding model: {embedding_model}")
print(f"Chunk size: {chunk_size}")
print("✓ Configuration setup complete")
# Out:
# LLM model: gpt-4o
# Embedding model: local:BAAI/bge-small-en-v1.5
# Chunk size: 1024
# ✓ Configuration setup complete

# %% [markdown]
# ## 3. LlamaIndex Settings Configuration
#
# LlamaIndex uses global settings for embeddings, LLMs, and document processing. We'll use OpenRouter for the LLM and a local embedding model (no API key required).

# %%
from llama_index.core import Settings
from llama_index.llms.openrouter import OpenRouter
from llama_index.core.embeddings import resolve_embed_model
from llama_index.core.node_parser import SentenceSplitter

def configure_llamaindex_settings():
    """
    Configure LlamaIndex global settings for embeddings, LLM, and text processing.
    """
    # Set up LLM with OpenRouter
    model = get_config("llm.model")
    temperature = get_config("llm.temperature", 0.1)

    Settings.llm = OpenRouter(
        api_key=os.getenv("OPENROUTER_API_KEY"),
        model=model,
        temperature=temperature
    )
    print(f"✓ LLM configured: {model} (temperature: {temperature})")

    # Set up local embedding model (downloads locally first time, then cached)
    embedding_model = get_config("embeddings.model")
    Settings.embed_model = resolve_embed_model(embedding_model)
    print(f"✓ Embedding model configured: {embedding_model}")

    # Set up node parser for chunking
    chunk_size = get_config("embeddings.chunk_size")
    chunk_overlap = get_config("embeddings.chunk_overlap")

    Settings.node_parser = SentenceSplitter(
        chunk_size=chunk_size,
        chunk_overlap=chunk_overlap
    )
    print(f"✓ Text chunking configured: {chunk_size} chars with {chunk_overlap} overlap")

# Configure the settings using our hardcoded config
configure_llamaindex_settings()
print("✓ LlamaIndex settings configured successfully")
# Out:
# ✓ LLM configured: gpt-4o (temperature: 0.1)
# Loading weights:   0%|          | 0/199 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: BAAI/bge-small-en-v1.5
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✓ Embedding model configured: local:BAAI/bge-small-en-v1.5
# ✓ Text chunking configured: 1024 chars with 100 overlap
# ✓ LlamaIndex settings configured successfully

# %% [markdown]
# ## 4. Vector Store Setup
#
# We'll use LanceDB as our vector database to store document embeddings. LanceDB is a fast, serverless vector database that's perfect for RAG applications.

# %%
from llama_index.vector_stores.lancedb import LanceDBVectorStore

def create_vector_store():
    """
    Create and configure LanceDB vector store using config settings.

    Returns:
        LanceDBVectorStore: Configured vector store
    """
    try:
        import lancedb

        # Get configuration values
        vector_db_path = get_config("vector_store.path")
        table_name = get_config("vector_store.table_name")

        # Create storage directory
        Path(vector_db_path).parent.mkdir(parents=True, exist_ok=True)

        # Connect to LanceDB
        db = lancedb.connect(str(vector_db_path))
        print(f"✓ Connected to LanceDB at: {vector_db_path}")

        # Create vector store
        vector_store = LanceDBVectorStore(
            uri=str(vector_db_path),
            table_name=table_name
        )
        print(f"✓ LanceDB vector store created (table: {table_name})")

        return vector_store

    except Exception as e:
        print(f"Error creating vector store: {e}")
        return None

# Create the vector store using config
vector_store = create_vector_store()
if vector_store:
    print("✓ Vector store setup complete")
else:
    print("❌ Vector store setup failed")
# Out:
# WARNING:llama_index.vector_stores.lancedb.base:Table academic_papers doesn't exist yet. Please add some data to create it.
# ✓ Connected to LanceDB at: storage/papers_vectordb
# ✓ LanceDB vector store created (table: academic_papers)
# ✓ Vector store setup complete

# %% [markdown]
# ## 5. PDF Processing and Document Loading
#
# Now we'll create functions to load and process PDF files. We'll use LlamaIndex's native `SimpleDirectoryReader` which can handle PDFs directly without needing a custom processor.

# %%
from llama_index.core import SimpleDirectoryReader

def load_papers_from_folder() -> List:
    """
    Load and process all PDF papers from the configured folder using LlamaIndex's native loader.

    Returns:
        List[Document]: Processed documents ready for indexing
    """
    papers_folder = get_config("papers.folder")
    print(f"Loading papers from: {papers_folder}")

    papers_path = Path(papers_folder)
    if not papers_path.exists():
        print(f"Papers folder does not exist: {papers_path}")
        return []

    # Use LlamaIndex's SimpleDirectoryReader to load PDFs
    # This natively handles PDF parsing, text extraction, and metadata
    documents = SimpleDirectoryReader(papers_folder).load_data()

    print(f"✓ Loaded {len(documents)} documents")
    return documents

# Load the papers using config
documents = load_papers_from_folder()
if documents:
    print(f"Successfully loaded {len(documents)} documents")
    print(f"First document preview: {documents[0].text[:200]}...")
    print(f"First document metadata: {documents[0].metadata}")
else:
    print("No documents loaded")
# Out:
# Loading papers from: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents
# ✓ Loaded 229 documents
# Successfully loaded 229 documents
# First document preview: AI Agents vs. Agentic AI: A Conceptual
# Taxonomy, Applications and Challenges
# Ranjan Sapkota ∗‡, Konstantinos I. Roumeliotis †, Manoj Karkee ∗‡
# ∗Cornell University, Department of Environmental and Biol...
# First document metadata: {'page_label': '1', 'file_name': 'AI_Agents_vs_Agentic_AI.pdf', 'file_path': '/content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf', 'file_type': 'application/pdf', 'file_size': 3196781, 'creation_date': '2026-03-28', 'last_modified_date': '2026-03-28'}

# %% [markdown]
# ## 6. Creating the Vector Index
#
# The vector index is the core of our RAG system. It chunks documents, generates embeddings, and stores them in the vector database for efficient similarity search.

# %%
from llama_index.core import StorageContext, VectorStoreIndex, load_index_from_storage

def create_vector_index(documents: List,
                       vector_store,
                       force_rebuild: bool = False):
    """
    Create or load a vector index from documents using config settings.

    Args:
        documents (List): Documents to index
        vector_store: LanceDB vector store
        force_rebuild (bool): Force rebuild even if index exists

    Returns:
        VectorStoreIndex: The created or loaded index
    """
    index_storage_path = get_config("index.storage_path")
    index_path = Path(index_storage_path)
    index_path.mkdir(parents=True, exist_ok=True)

    # Check if index already exists
    index_store_file = index_path / "index_store.json"

    if not force_rebuild and index_store_file.exists():
        print("📁 Loading existing index...")
        try:
            # Recreate storage context with vector store
            storage_context = StorageContext.from_defaults(
                persist_dir=str(index_path),
                vector_store=vector_store
            )

            # Load existing index
            index = load_index_from_storage(storage_context)
            print("✓ Successfully loaded existing index")
            return index

        except Exception as e:
            print(f"⚠️  Error loading existing index: {e}")
            print("Creating new index...")

    if not documents:
        print("❌ No documents to index")
        return None

    print("🔨 Creating new vector index...")
    start_time = time.time()

    # Create storage context with vector store
    storage_context = StorageContext.from_defaults(vector_store=vector_store)

    # Create index with progress bar
    index = VectorStoreIndex.from_documents(
        documents,
        storage_context=storage_context,
        show_progress=True
    )

    end_time = time.time()
    print(f"✓ Index created in {end_time - start_time:.2f} seconds")

    # Save index to storage
    print("💾 Saving index to storage...")
    index.storage_context.persist(persist_dir=str(index_path))
    print("✓ Index saved successfully")

    return index

# Create the vector index using config
index = create_vector_index(
    documents=documents,
    vector_store=vector_store,
    force_rebuild=False  # Set to True to force rebuild
)

if index:
    print("✓ Vector index ready for querying")
else:
    print("❌ Failed to create vector index")
# Out:
# 🔨 Creating new vector index...
# Applying transformations:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/406 [00:00<?, ?it/s]
# ✓ Index created in 257.12 seconds
# 💾 Saving index to storage...
# ✓ Index saved successfully
# ✓ Vector index ready for querying

# %% [markdown]
# ## 7. Setting Up the Query Engine
#
# The query engine combines a retriever (to find relevant documents) with an LLM (to generate responses). This is where the "Augmented Generation" part of RAG happens.

# %%
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever

def setup_query_engine(index):
    """
    Setup the query engine for semantic search and response generation using config settings.

    Args:
        index: The vector index to query

    Returns:
        RetrieverQueryEngine: Configured query engine
    """
    if not index:
        print("❌ Index not available. Please create index first.")
        return None

    try:
        # Get similarity top k from config
        similarity_top_k = get_config("index.similarity_top_k")

        # Create retriever - this finds the most similar document chunks
        retriever = VectorIndexRetriever(
            index=index,
            similarity_top_k=similarity_top_k,
        )
        print(f"✓ Retriever configured to find top {similarity_top_k} similar chunks")

        # Create query engine - this combines retrieval with LLM generation
        query_engine = RetrieverQueryEngine(retriever=retriever)
        print("✓ Query engine setup successfully")

        return query_engine

    except Exception as e:
        print(f"❌ Error setting up query engine: {e}")
        return None

# Setup the query engine using config
query_engine = setup_query_engine(index)

if query_engine:
    print("🚀 RAG system is ready for queries!")
else:
    print("❌ Failed to setup query engine")
# Out:
# ✓ Retriever configured to find top 5 similar chunks
# ✓ Query engine setup successfully
# 🚀 RAG system is ready for queries!

# %%
def extract_paper_title_from_text(text: str, max_length: int = 200) -> str:
    """
    Extract the paper title from the document text.

    Args:
        text (str): Document text content
        max_length (int): Maximum length for title extraction

    Returns:
        str: Extracted title or fallback
    """
    if not text:
        return "Unknown Title"

    # Split into lines and clean them
    lines = [line.strip() for line in text.split('\n') if line.strip()]

    if not lines:
        return "Unknown Title"

    # Look for title patterns - usually the first substantial line
    # Skip very short lines, page numbers, headers
    for line in lines[:10]:  # Check first 10 lines
        # Skip lines that look like headers, page numbers, or metadata
        if (len(line) > 15 and
            not line.isdigit() and
            not line.startswith(('Page', 'arXiv:', 'doi:', 'http', 'www')) and
            not all(c.isupper() or c.isspace() for c in line) and  # Skip all-caps headers
            '.' in line or len(line) > 30):  # Likely a title if it has punctuation or is long

            # Clean up the title
            title = line.strip()

            # Remove common prefixes/suffixes
            prefixes_to_remove = ['Title:', 'Abstract:', 'Paper:', 'Research:']
            for prefix in prefixes_to_remove:
                if title.startswith(prefix):
                    title = title[len(prefix):].strip()

            # Truncate if too long
            if len(title) > max_length:
                title = title[:max_length].strip() + "..."

            return title

    # Fallback: use first non-empty line, truncated
    first_line = lines[0] if lines else "Unknown Title"
    if len(first_line) > max_length:
        first_line = first_line[:max_length].strip() + "..."

    return first_line

def extract_paper_authors_from_text(text: str) -> str:
    """
    Extract authors from the document text.

    Args:
        text (str): Document text content

    Returns:
        str: Extracted authors or "Unknown Authors"
    """
    if not text:
        return "Unknown Authors"

    lines = [line.strip() for line in text.split('\n') if line.strip()]

    # Look for author patterns in first 20 lines
    for i, line in enumerate(lines[:20]):
        # Skip the title line (usually first substantial line)
        if i == 0:
            continue

        # Look for author patterns
        if (len(line) > 5 and
            not line.isdigit() and
            not line.startswith(('Abstract', 'Introduction', 'Page', 'arXiv:', 'doi:', 'http')) and
            ('University' in line or 'Institute' in line or
             ',' in line or 'Department' in line or
             '@' in line or  # Email addresses often indicate authors
             any(char.isupper() for char in line))):  # Names often have capitals

            # Clean up author line
            authors = line.strip()

            # Remove common prefixes
            prefixes_to_remove = ['Authors:', 'By:', 'Author:']
            for prefix in prefixes_to_remove:
                if authors.startswith(prefix):
                    authors = authors[len(prefix):].strip()

            # Truncate if too long
            if len(authors) > 150:
                authors = authors[:150].strip() + "..."

            return authors

    return "Unknown Authors"

print("📝 Title and Author extraction functions loaded successfully!")
# Out:
# 📝 Title and Author extraction functions loaded successfully!

# %% [markdown]
# ## 8. Search and Query Functions
#
# Now let's create functions to search through our academic papers and extract detailed information about sources and metadata.

# %%
# Updated list_indexed_papers function with title extraction
def list_indexed_papers_improved(documents: List) -> List[Dict[str, any]]:
    """
    List all papers that have been indexed with their metadata.
    Extracts actual paper titles and authors from document content.

    Args:
        documents (List): List of loaded documents

    Returns:
        List[Dict[str, any]]: List of paper information
    """
    papers = []
    processed_files = set()  # Track unique files to avoid duplicates

    for doc in documents:
        try:
            metadata = doc.metadata
            file_path = metadata.get("file_path", "")
            file_name = Path(file_path).stem if file_path else "Unknown"

            # Skip if we've already processed this file
            if file_path in processed_files:
                continue
            processed_files.add(file_path)

            # Extract title and authors from document text
            doc_text = doc.text if hasattr(doc, 'text') else ""
            extracted_title = extract_paper_title_from_text(doc_text)
            extracted_authors = extract_paper_authors_from_text(doc_text)

            paper_info = {
                "file_name": file_name,
                "file_path": file_path,
                "title": extracted_title,
                "authors": extracted_authors,
                "page_count": metadata.get("page_count", 0),
                "file_size": metadata.get("file_size", 0),
                "file_size_mb": round(metadata.get("file_size", 0) / (1024 * 1024), 2) if metadata.get("file_size") else 0,
                "total_pages": metadata.get("total_pages", "Unknown"),
                "page_label": metadata.get("page_label", ""),
            }

            papers.append(paper_info)

        except Exception as e:
            print(f"Error processing document: {e}")

    return papers

# Re-list papers with improved title extraction
print("🔄 Re-processing papers with improved title extraction...")
papers_list_improved = list_indexed_papers_improved(documents)

print(f"📚 Found {len(papers_list_improved)} unique papers in the index:")
print("=" * 80)

for i, paper in enumerate(papers_list_improved[:10], 1):  # Show first 10 papers
    print(f"{i}. 📄 {paper['title']}")
    print(f"   👥 Authors: {paper['authors']}")
    print(f"   📁 File: {paper['file_name']}")
    print(f"   💾 Size: {paper['file_size_mb']} MB")
    if paper.get('page_label'):
        print(f"   📖 Page: {paper['page_label']}")
    print("-" * 60)

print(f"\n✅ Successfully extracted titles for {len(papers_list_improved)} papers!")
if len(papers_list_improved) > 10:
    print(f"📝 Showing first 10 papers. Total: {len(papers_list_improved)} papers available.")
# Out:
# 🔄 Re-processing papers with improved title extraction...
# 📚 Found 5 unique papers in the index:
# ================================================================================
# 1. 📄 AI Agents vs. Agentic AI: A Conceptual
#    👥 Authors: Taxonomy, Applications and Challenges
#    📁 File: AI_Agents_vs_Agentic_AI
#    💾 Size: 3.05 MB
#    📖 Page: 1
# ------------------------------------------------------------
# 2. 📄 THE LANDSCAPE OF EMERGING AI A GENT ARCHITECTURES
#    👥 Authors: FOR REASONING , PLANNING , AND TOOL CALLING : A S URVEY
#    📁 File: Emerging_Agent_Architectures
#    💾 Size: 1.58 MB
#    📖 Page: 1
# ------------------------------------------------------------
# 3. 📄 From LLM Reasoning to Autonomous AI Agents:
#    👥 Authors: From LLM Reasoning to Autonomous AI Agents:
#    📁 File: LLMReasoning_to_Autonomous_Agents
#    💾 Size: 16.21 MB
#    📖 Page: 1
# ------------------------------------------------------------
# 4. 📄 The Rise and Potential of Large Language Model
#    👥 Authors: Based Agents: A Survey
#    📁 File: Rise_and_Potential_LLM_Agents
#    💾 Size: 6.52 MB
#    📖 Page: 1
# ------------------------------------------------------------
# 5. 📄 A Comprehensive Survey of Self-Evolving AI Agents
#    👥 Authors: A New Paradigm Bridging Foundation Models and Lifelong Agentic Systems
#    📁 File: survey_of_self_evolving_agents
#    💾 Size: 10.56 MB
#    📖 Page: 1
# ------------------------------------------------------------
#
# ✅ Successfully extracted titles for 5 papers!

# %%
# Enhanced search function with improved metadata extraction
def search_papers_improved(query_engine, query: str, include_metadata: bool = True) -> Dict[str, any]:
    """
    Search for relevant papers based on the query with improved title extraction.

    Args:
        query_engine: The configured query engine
        query (str): Search query
        include_metadata (bool): Whether to include detailed metadata

    Returns:
        Dict[str, any]: Search results with response and sources
    """
    if not query_engine:
        return {
            "success": False,
            "error": "Query engine not initialized.",
            "response": "",
            "sources": [],
        }

    try:
        print(f"🔍 Searching for: '{query}'")
        start_time = time.time()

        # Query the RAG system
        response = query_engine.query(query)

        end_time = time.time()

        # Extract source information from retrieved nodes with title extraction
        sources = []
        if hasattr(response, "source_nodes"):
            for node in response.source_nodes:
                # Extract title from the node text
                node_text = node.text if hasattr(node, 'text') else ""
                extracted_title = extract_paper_title_from_text(node_text, max_length=100)
                extracted_authors = extract_paper_authors_from_text(node_text)

                source_info = {
                    "text": (
                        node.text[:500] + "..."
                        if len(node.text) > 500
                        else node.text
                    ),
                    "score": getattr(node, "score", 0.0),
                    "extracted_title": extracted_title,
                    "extracted_authors": extracted_authors,
                }

                # Add metadata if available and requested
                if include_metadata and hasattr(node, "metadata"):
                    metadata = node.metadata
                    source_info.update({
                        "file_name": metadata.get("file_name", "Unknown"),
                        "file_path": metadata.get("file_path", ""),
                        "page_label": metadata.get("page_label", ""),
                        "file_size_mb": round(metadata.get("file_size", 0) / (1024 * 1024), 2) if metadata.get("file_size") else 0,
                    })

                sources.append(source_info)

        result = {
            "success": True,
            "response": str(response),
            "sources": sources,
            "query": query,
            "search_time": end_time - start_time,
            "num_sources": len(sources),
        }

        print(f"✓ Search completed in {end_time - start_time:.2f} seconds")
        print(f"📚 Found {len(sources)} relevant sources")

        return result

    except Exception as e:
        print(f"❌ Error during search: {e}")
        return {"success": False, "error": str(e), "response": "", "sources": []}

print("🔍 Enhanced search function with title extraction loaded!")
# Out:
# 🔍 Enhanced search function with title extraction loaded!

# %%
# Test the improved search with title extraction
def ask_question_improved(query_engine, question: str, show_sources: bool = True):
    """
    Ask a custom question to the RAG system with improved title extraction.

    Args:
        query_engine: The configured query engine
        question (str): Your question about the papers
        show_sources (bool): Whether to display source information
    """
    print(f"❓ Question: {question}")
    print("=" * 80)

    result = search_papers_improved(query_engine, question, include_metadata=True)

    if result["success"]:
        print(f"💡 Answer:")
        print(result["response"])
        print(f"\n📊 Search completed in {result['search_time']:.2f} seconds")
        print(f"📚 Found {result['num_sources']} relevant sources")

        if show_sources and result["sources"]:
            print(f"\n📖 Source Details:")
            print("-" * 60)
            for i, source in enumerate(result["sources"], 1):
                print(f"\n{i}. 📄 Paper: {source.get('extracted_title', 'Unknown Title')}")
                print(f"   👥 Authors: {source.get('extracted_authors', 'Unknown Authors')}")
                print(f"   📁 File: {source.get('file_name', 'Unknown')}")
                if source.get('page_label'):
                    print(f"   📖 Page: {source['page_label']}")
                print(f"   🎯 Relevance Score: {source.get('score', 0):.3f}")
                print(f"   📝 Text Preview: {source['text'][:200]}...")

    else:
        print(f"❌ Error: {result['error']}")

# Test with the improved version
test_question = "What are the main architectural patterns for agent systems?"

if query_engine:
    print("🧪 Testing improved search with title extraction:")
    print("=" * 80)
    ask_question_improved(query_engine, test_question, show_sources=True)
else:
    print("❌ Query engine not available")
# Out:
# 🧪 Testing improved search with title extraction:
# ================================================================================
# ❓ Question: What are the main architectural patterns for agent systems?
# ================================================================================
# 🔍 Searching for: 'What are the main architectural patterns for agent systems?'
# ✓ Search completed in 6.04 seconds
# 📚 Found 5 relevant sources
# 💡 Answer:
# Agent systems are architecturally designed with multiple components that collaborate to enable autonomous decision-making and execution. At the core is the Foundation Model, often a large language model (LLM), serving as the central reasoning engine. Supporting this are modules like the Perception Module, which gathers and interprets environmental data, and the Planning Module, which breaks down complex tasks into manageable sub-tasks. These components collectively support hierarchical reasoning and dynamic task execution, ensuring agents function effectively in complex and dynamic settings.
#
# 📊 Search completed in 6.04 seconds
# 📚 Found 5 relevant sources
#
# 📖 Source Details:
# ------------------------------------------------------------
#
# 1. 📄 Paper: emphasizes emergent capabilities including Multi-Agent Col-
#    👥 Authors: emphasizes emergent capabilities including Multi-Agent Col-
#    📁 File: AI_Agents_vs_Agentic_AI.pdf
#    📖 Page: 11
#    🎯 Relevance Score: 0.728
#    📝 Text Preview: The figure further
# emphasizes emergent capabilities including Multi-Agent Col-
# laboration, System Coordination, Shared Context, and Task
# Decomposition, all encapsulated within a dotted boundary
# that s...
#
# 2. 📄 Paper: task. In single agent patterns there is no feedback mechanism from other AI agents; however, there m...
#    👥 Authors: Multi-Agent Architectures. These architectures involve two or more agents, where each agent can utilize the same
#    📁 File: Emerging_Agent_Architectures.pdf
#    📖 Page: 3
#    🎯 Relevance Score: 0.688
#    📝 Text Preview: task. In single agent patterns there is no feedback mechanism from other AI agents; however, there may be options for
# humans to provide feedback that guides the agent.
# Multi-Agent Architectures. These...
#
# 3. 📄 Paper: tural distinction underpins profound differences in scalability,
#    👥 Authors: tural distinction underpins profound differences in scalability,
#    📁 File: AI_Agents_vs_Agentic_AI.pdf
#    📖 Page: 2
#    🎯 Relevance Score: 0.687
#    📝 Text Preview: This architec-
# tural distinction underpins profound differences in scalability,
# adaptability, and application scope.
# Understanding and formalizing the taxonomy between these
# two paradigms (AI Agents a...
#
# 4. 📄 Paper: Fig. 2: Mindmap of Research Questions relevant to AI
#    👥 Authors: Agentic AI
#    📁 File: AI_Agents_vs_Agentic_AI.pdf
#    📖 Page: 3
#    🎯 Relevance Score: 0.681
#    📝 Text Preview: AI Agents
# &
# Agentic AI
# Architecture
# Mechanisms
# Scope/
# Complexity
# Interaction
# Autonomy
# Fig. 2: Mindmap of Research Questions relevant to AI
# Agents and Agentic AI. Each color-coded branch represents
# a k...
#
# 5. 📄 Paper: agentic systems.
#    👥 Authors: The remainder of this survey is organised as follows. Section 2 presents preliminaries on AI agents and
#    📁 File: survey_of_self_evolving_agents.pdf
#    📖 Page: 6
#    🎯 Relevance Score: 0.667
#    📝 Text Preview: agentic systems.
# The remainder of this survey is organised as follows. Section 2 presents preliminaries on AI agents and
# multi-agent systems, including their definitions, key components, representativ...

# %%
def search_papers(query_engine, query: str, include_metadata: bool = True) -> Dict[str, any]:
    """
    Search for relevant papers based on the query.

    Args:
        query_engine: The configured query engine
        query (str): Search query
        include_metadata (bool): Whether to include detailed metadata

    Returns:
        Dict[str, any]: Search results with response and sources
    """
    if not query_engine:
        return {
            "success": False,
            "error": "Query engine not initialized.",
            "response": "",
            "sources": [],
        }

    try:
        print(f"🔍 Searching for: '{query}'")
        start_time = time.time()

        # Query the RAG system
        response = query_engine.query(query)

        end_time = time.time()

        # Extract source information from retrieved nodes
        sources = []
        if hasattr(response, "source_nodes"):
            for node in response.source_nodes:
                source_info = {
                    "text": (
                        node.text[:500] + "..."
                        if len(node.text) > 500
                        else node.text
                    ),
                    "score": getattr(node, "score", 0.0),
                }

                # Add metadata if available and requested
                if include_metadata and hasattr(node, "metadata"):
                    metadata = node.metadata
                    source_info.update({
                        "file_name": metadata.get("file_name", "Unknown"),
                        "title": metadata.get("title", "Unknown Title"),
                        "authors": metadata.get("authors", "Unknown Authors"),
                        "page_count": metadata.get("page_count", 0),
                        "has_abstract": metadata.get("has_abstract", False),
                    })

                sources.append(source_info)

        result = {
            "success": True,
            "response": str(response),
            "sources": sources,
            "query": query,
            "search_time": end_time - start_time,
            "num_sources": len(sources),
        }

        print(f"✓ Search completed in {end_time - start_time:.2f} seconds")
        print(f"📚 Found {len(sources)} relevant sources")

        return result

    except Exception as e:
        print(f"❌ Error during search: {e}")
        return {"success": False, "error": str(e), "response": "", "sources": []}

# Test the search function with a sample query
test_query = "What are the main types of AI agents discussed in these papers?"
result = search_papers(query_engine, test_query)

if result["success"]:
    print(f"\n📝 Response Preview: {result['response']}")
    print(f"📊 Number of sources: {result['num_sources']}")
    print(f"⏱️  Search time: {result['search_time']:.2f} seconds")
else:
    print(f"❌ Search failed: {result['error']}")
# Out:
# 🔍 Searching for: 'What are the main types of AI agents discussed in these papers?'
# ✓ Search completed in 4.07 seconds
# 📚 Found 5 relevant sources
#
# 📝 Response Preview: The papers explore different types of AI agents, including web automation agents, multi-agent systems, and retrieval-augmented generative agents. Web automation agents utilize large foundation models to automate web tasks. Multi-agent systems consist of multiple agents collaborating, frequently employing reinforcement learning for tasks such as query resolution and analysis. Retrieval-augmented generative agents are tailored for scientific research, improving information retrieval and synthesis.
# 📊 Number of sources: 5
# ⏱️  Search time: 4.07 seconds

# %% [markdown]
# ## 9. Paper Information and Metadata
#
# Let's create functions to list and get detailed information about the papers in our index.

# %%
def list_indexed_papers(documents: List) -> List[Dict[str, any]]:
    """
    List all papers that have been indexed with their metadata.

    Args:
        documents (List): List of loaded documents

    Returns:
        List[Dict[str, any]]: List of paper information
    """
    papers = []

    for doc in documents:
        try:
            metadata = doc.metadata
            file_path = metadata.get("file_path", "")
            file_name = Path(file_path).stem if file_path else "Unknown"

            paper_info = {
                "file_name": file_name,
                "file_path": file_path,
                "title": metadata.get("title", file_name),
                "authors": metadata.get("authors", "Unknown"),
                "page_count": metadata.get("page_count", 0),
                "file_size": metadata.get("file_size", 0),
                "file_size_mb": round(metadata.get("file_size", 0) / (1024 * 1024), 2) if metadata.get("file_size") else 0,
                "total_pages": metadata.get("total_pages", "Unknown"),
            }

            papers.append(paper_info)

        except Exception as e:
            print(f"Error processing document: {e}")

    return papers

# List all indexed papers
papers_list = list_indexed_papers(documents)

print(f"📚 Found {len(papers_list)} papers in the index:")
print("=" * 60)

for i, paper in enumerate(papers_list, 1):
    print(f"{i}. {paper['file_name']}")
    print(f"   File Path: {paper['file_path']}")
    print(f"   Total Pages: {paper.get('total_pages', 'Unknown')}")
    print(f"   Size: {paper['file_size_mb']} MB")
    print("-" * 40)
# Out:
# 📚 Found 229 papers in the index:
# ============================================================
# 1. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 2. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 3. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 4. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 5. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 6. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 7. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 8. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 9. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 10. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 11. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 12. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 13. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 14. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 15. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 16. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 17. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 18. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 19. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 20. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 21. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 22. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 23. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 24. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 25. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 26. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 27. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 28. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 29. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 30. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 31. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 32. AI_Agents_vs_Agentic_AI
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/AI_Agents_vs_Agentic_AI.pdf
#    Total Pages: Unknown
#    Size: 3.05 MB
# ----------------------------------------
# 33. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 34. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 35. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 36. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 37. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 38. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 39. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 40. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 41. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 42. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 43. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 44. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 45. Emerging_Agent_Architectures
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Emerging_Agent_Architectures.pdf
#    Total Pages: Unknown
#    Size: 1.58 MB
# ----------------------------------------
# 46. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 47. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 48. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 49. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 50. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 51. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 52. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 53. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 54. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 55. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 56. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 57. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 58. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 59. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 60. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 61. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 62. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 63. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 64. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 65. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 66. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 67. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 68. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 69. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 70. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 71. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 72. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 73. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 74. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 75. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 76. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 77. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 78. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 79. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 80. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 81. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 82. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 83. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 84. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 85. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 86. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 87. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 88. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 89. LLMReasoning_to_Autonomous_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/LLMReasoning_to_Autonomous_Agents.pdf
#    Total Pages: Unknown
#    Size: 16.21 MB
# ----------------------------------------
# 90. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 91. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 92. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 93. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 94. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 95. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 96. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 97. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 98. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 99. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 100. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 101. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 102. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 103. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 104. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 105. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 106. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 107. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 108. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 109. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 110. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 111. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 112. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 113. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 114. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 115. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 116. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 117. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 118. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 119. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 120. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 121. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 122. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 123. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 124. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 125. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 126. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 127. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 128. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 129. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 130. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 131. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 132. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 133. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 134. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 135. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 136. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 137. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 138. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 139. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 140. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 141. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 142. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 143. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 144. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 145. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 146. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 147. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 148. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 149. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 150. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 151. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 152. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 153. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 154. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 155. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 156. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 157. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 158. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 159. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 160. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 161. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 162. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 163. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 164. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 165. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 166. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 167. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 168. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 169. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 170. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 171. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 172. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 173. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 174. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 175. Rise_and_Potential_LLM_Agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/Rise_and_Potential_LLM_Agents.pdf
#    Total Pages: Unknown
#    Size: 6.52 MB
# ----------------------------------------
# 176. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 177. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 178. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 179. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 180. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 181. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 182. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 183. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 184. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 185. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 186. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 187. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 188. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 189. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 190. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 191. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 192. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 193. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 194. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 195. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 196. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 197. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 198. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 199. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 200. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 201. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 202. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 203. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 204. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 205. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 206. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 207. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 208. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 209. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 210. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 211. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 212. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 213. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 214. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 215. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 216. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 217. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 218. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 219. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 220. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 221. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 222. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 223. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 224. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 225. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 226. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 227. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 228. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------
# 229. survey_of_self_evolving_agents
#    File Path: /content/drive/MyDrive/outskill/ai-accelerator-C5/Day_6/session_2/papers/agents/survey_of_self_evolving_agents.pdf
#    Total Pages: Unknown
#    Size: 10.56 MB
# ----------------------------------------

# %% [markdown]
# ## 11. Advanced Query Examples
#
# Now let's test our RAG system with various types of research queries to demonstrate its capabilities.

# %%
def run_example_queries(query_engine):
    """
    Run a series of example queries to demonstrate RAG capabilities.

    Args:
        query_engine: The configured query engine
    """
    example_queries = [
        {
            "category": "Agent Types",
            "query": "What are the main types of AI agents discussed in these papers?",
        },
        {
            "category": "Technical Comparison",
            "query": "How do LLM-based agents differ from traditional AI agents?",
        },
        {
            "category": "Challenges",
            "query": "What are the current challenges in developing autonomous agents?",
        },
        {
            "category": "Evaluation",
            "query": "What evaluation methods are used for AI agents?",
        },
        {
            "category": "Architecture",
            "query": "Describe the common architectural patterns for agent systems.",
        },
        {
            "category": "Applications",
            "query": "What are the practical applications of AI agents mentioned in the literature?",
        },
    ]

    print("🧪 Running Example Queries")
    print("=" * 60)

    for i, example in enumerate(example_queries, 1):
        print(f"\n{i}. {example['category']}")
        print(f"Q: {example['query']}")
        print("-" * 50)

        result = search_papers(query_engine, example["query"])

        if result["success"]:
            # Display truncated response
            response = result["response"]
            if len(response) > 400:
                response = response[:400] + "..."

            print(f"A: {response}")
            print(f"📚 Sources: {result['num_sources']} | ⏱️  Time: {result['search_time']:.2f}s")
        else:
            print(f"❌ Error: {result['error']}")

        print()

# Run the example queries
if query_engine:
    run_example_queries(query_engine)
else:
    print("❌ Query engine not available for examples")
# Out:
# 🧪 Running Example Queries
# ============================================================
#
# 1. Agent Types
# Q: What are the main types of AI agents discussed in these papers?
# --------------------------------------------------
# 🔍 Searching for: 'What are the main types of AI agents discussed in these papers?'
# ✓ Search completed in 4.42 seconds
# 📚 Found 5 relevant sources
# A: The papers cover a range of AI agents, such as web agents for web automation with large foundation models, multi-agent actor-critic generative AI for query resolution and analysis, retrieval-augmented generative agents for scientific research, and models as agents for optimizing multi-step predictions in model-based multi-agent reinforcement learning. They also emphasize multi-agent embodied AI, h...
# 📚 Sources: 5 | ⏱️  Time: 4.42s
#
#
# 2. Technical Comparison
# Q: How do LLM-based agents differ from traditional AI agents?
# --------------------------------------------------
# 🔍 Searching for: 'How do LLM-based agents differ from traditional AI agents?'
# ✓ Search completed in 5.59 seconds
# 📚 Found 5 relevant sources
# A: LLM-based agents differ from traditional AI agents by leveraging large language models as their core, which provides a more adaptable and general foundation. This allows them to operate effectively across various scenarios, unlike traditional AI agents that often depend on specific algorithms tailored for particular tasks. LLM-based agents exhibit versatile capabilities, such as advanced text unde...
# 📚 Sources: 5 | ⏱️  Time: 5.59s
#
#
# 3. Challenges
# Q: What are the current challenges in developing autonomous agents?
# --------------------------------------------------
# 🔍 Searching for: 'What are the current challenges in developing autonomous agents?'
# ✓ Search completed in 5.32 seconds
# 📚 Found 5 relevant sources
# A: The development of autonomous agents is currently challenged by several factors. For AI Agents, these challenges include a lack of causal reasoning, issues stemming from large language models like hallucinations and shallow reasoning, and incomplete agentic properties such as autonomy and proactivity. Additionally, there are difficulties in long-horizon planning and recovery, often due to reliance...
# 📚 Sources: 5 | ⏱️  Time: 5.32s
#
#
# 4. Evaluation
# Q: What evaluation methods are used for AI agents?
# --------------------------------------------------
# 🔍 Searching for: 'What evaluation methods are used for AI agents?'
# ✓ Search completed in 1.48 seconds
# 📚 Found 5 relevant sources
# A: AI agents are evaluated using a variety of methods that focus on different aspects of their performance. These include benchmark-based evaluations, which assess agents on structured tasks with standardized metrics. For tool and API-driven agents, evaluations focus on their ability to use external APIs and functions effectively. Web navigation and browsing agents are tested on their interaction wit...
# 📚 Sources: 5 | ⏱️  Time: 1.48s
#
#
# 5. Architecture
# Q: Describe the common architectural patterns for agent systems.
# --------------------------------------------------
# 🔍 Searching for: 'Describe the common architectural patterns for agent systems.'
# ✓ Search completed in 5.35 seconds
# 📚 Found 5 relevant sources
# A: Agent systems generally follow two primary architectural patterns: vertical and horizontal architectures. In vertical architectures, one agent takes on a leadership role, with other agents reporting to it, forming a hierarchical structure. This setup can involve either exclusive communication with the lead agent or shared interactions among all agents. On the other hand, horizontal architectures p...
# 📚 Sources: 5 | ⏱️  Time: 5.35s
#
#
# 6. Applications
# Q: What are the practical applications of AI agents mentioned in the literature?
# --------------------------------------------------
# 🔍 Searching for: 'What are the practical applications of AI agents mentioned in the literature?'
# ✓ Search completed in 3.63 seconds
# 📚 Found 5 relevant sources
# A: AI agents are applied in numerous practical domains. In healthcare, they are utilized for clinical diagnosis, personalized treatment planning, mental health support, and pharmaceutical research. In finance, they assist with forecasting and risk analysis. In scientific research, AI agents automate literature reviews and experimental design. Additionally, in software engineering, they aid in generat...
# 📚 Sources: 5 | ⏱️  Time: 3.63s

# %% [markdown]
# ## 12. Interactive Query Interface
#
# Let's create an interactive function that allows you to ask custom questions about the papers.

# %%
def ask_question(query_engine, question: str, show_sources: bool = True):
    """
    Ask a custom question to the RAG system and display results.

    Args:
        query_engine: The configured query engine
        question (str): Your question about the papers
        show_sources (bool): Whether to display source information
    """
    print(f"❓ Question: {question}")
    print("=" * 60)

    result = search_papers(query_engine, question, include_metadata=True)

    if result["success"]:
        print(f"💡 Answer:")
        print(result["response"])
        print(f"\n📊 Search completed in {result['search_time']:.2f} seconds")
        print(f"📚 Found {result['num_sources']} relevant sources")

        if show_sources and result["sources"]:
            print(f"\n📖 Source Details:")
            print("-" * 40)
            for i, source in enumerate(result["sources"], 1):
                print(f"\n{i}. Score: {source.get('score', 0):.3f}")
                print(f"   Text: {source['text'][:200]}...")

    else:
        print(f"❌ Error: {result['error']}")

# Example usage - you can modify this question
custom_question = "What are the key ethical considerations for AI agents?"

if query_engine:
    ask_question(query_engine, custom_question, show_sources=True)
else:
    print("❌ Query engine not available")
# Out:
# ❓ Question: What are the key ethical considerations for AI agents?
# ============================================================
# 🔍 Searching for: 'What are the key ethical considerations for AI agents?'
# ✓ Search completed in 3.96 seconds
# 📚 Found 5 relevant sources
# 💡 Answer:
# Key ethical considerations for AI agents include accountability, oversight, and value alignment. In environments where multiple agents collaborate, it can be challenging to assign responsibility for outcomes. Ensuring fairness is critical, as biases in data can lead to skewed decisions and systemic inequities. Value alignment is essential to prevent agents from optimizing for goals that diverge from human intent, which could result in behavior inconsistent with ethical norms or user expectations. Addressing these considerations requires governance frameworks and oversight mechanisms to ensure responsible deployment and maintain ethical integrity.
#
# 📊 Search completed in 3.96 seconds
# 📚 Found 5 relevant sources
#
# 📖 Source Details:
# ----------------------------------------
#
# 1. Score: 0.653
#    Text: for errors or unintended consequences. This ambiguity
# complicates legal liability, regulatory compliance, and
# user trust, especially in domains such as healthcare,
# finance, or defense. Furthermore, bi...
#
# 2. Score: 0.618
#    Text: For
# example, a fact-checking agent fed with tampered data
# could unintentionally legitimize false claims, which are
# then integrated into downstream reasoning by summa-
# rization or decision-making agent...
#
# 3. Score: 0.614
#    Text: Acknowledgements
# Thanks to Professor Guoyu Wang for carefully reviewing the ethics of the article. Thanks to Jinzhu
# Xiong for her excellent drawing skills to present an amazing performance of Figure 1...
#
# 4. Score: 0.611
#    Text: AI Agents vs. Agentic AI: A Conceptual
# Taxonomy, Applications and Challenges
# Ranjan Sapkota ∗‡, Konstantinos I. Roumeliotis †, Manoj Karkee ∗‡
# ∗Cornell University, Department of Environmental and Biol...
#
# 5. Score: 0.604
#    Text: Together, these pathways will
# redefine AI Agents from static tools into adaptive cognitive
# systems capable of autonomous yet controllable operation in
# dynamic digital environments.
# Agentic AI, as a na...

# %% [markdown]
# ## 13. System Performance and Statistics
#
# Let's create functions to analyze and display performance statistics of our RAG system.

# %%
def display_system_stats(papers_list, vector_store, index):
    """
    Display comprehensive statistics about the RAG system.

    Args:
        papers_list: List of indexed papers
        vector_store: The vector store instance
        index: The vector index
    """
    print("📊 RAG System Statistics")
    print("=" * 50)

    # Paper statistics
    total_papers = len(papers_list)
    total_pages = sum(paper.get('page_count', 0) for paper in papers_list)
    total_size_mb = sum(paper.get('file_size_mb', 0) for paper in papers_list)

    print(f"📚 Document Statistics:")
    print(f"   Total Papers: {total_papers}")
    print(f"   Total Pages: {total_pages}")
    print(f"   Total Size: {total_size_mb:.2f} MB")
    print(f"   Average Pages per Paper: {total_pages/total_papers:.1f}" if total_papers > 0 else "   Average Pages: N/A")

    # Index statistics
    if index:
        print(f"\n🗂️  Index Statistics:")
        print(f"   Index Type: Vector Store Index")
        print(f"   Embedding Model: {get_config('api.openai.embedding_model', 'text-embedding-3-small')}")
        print(f"   LLM Model: {get_config('api.openai.model', 'gpt-4o-mini')}")

    # Storage paths
    print(f"\n💾 Storage Locations:")
    print(f"   Papers Folder: papers/agents")
    print(f"   Vector Database: storage/papers_vectordb")
    print(f"   Index Storage: storage/papers_index")

    # Recent papers by modification time
    if papers_list:
        print(f"\n📋 Paper Titles:")
        for i, paper in enumerate(papers_list, 1):
            title = paper['title']
            if len(title) > 50:
                title = title[:47] + "..."
            print(f"   {i}. {title}")

# Display system statistics
display_system_stats(papers_list, vector_store, index)
print("\n✅ RAG System Analysis Complete!")
# Out:
# 📊 RAG System Statistics
# ==================================================
# 📚 Document Statistics:
#    Total Papers: 229
#    Total Pages: 0
#    Total Size: 1962.34 MB
#    Average Pages per Paper: 0.0
#
# 🗂️  Index Statistics:
#    Index Type: Vector Store Index
#    Embedding Model: text-embedding-3-small
#    LLM Model: gpt-4o-mini
#
# 💾 Storage Locations:
#    Papers Folder: papers/agents
#    Vector Database: storage/papers_vectordb
#    Index Storage: storage/papers_index
#
# 📋 Paper Titles:
#    1. AI_Agents_vs_Agentic_AI
#    2. AI_Agents_vs_Agentic_AI
#    3. AI_Agents_vs_Agentic_AI
#    4. AI_Agents_vs_Agentic_AI
#    5. AI_Agents_vs_Agentic_AI
#    6. AI_Agents_vs_Agentic_AI
#    7. AI_Agents_vs_Agentic_AI
#    8. AI_Agents_vs_Agentic_AI
#    9. AI_Agents_vs_Agentic_AI
#    10. AI_Agents_vs_Agentic_AI
#    11. AI_Agents_vs_Agentic_AI
#    12. AI_Agents_vs_Agentic_AI
#    13. AI_Agents_vs_Agentic_AI
#    14. AI_Agents_vs_Agentic_AI
#    15. AI_Agents_vs_Agentic_AI
#    16. AI_Agents_vs_Agentic_AI
#    17. AI_Agents_vs_Agentic_AI
#    18. AI_Agents_vs_Agentic_AI
#    19. AI_Agents_vs_Agentic_AI
#    20. AI_Agents_vs_Agentic_AI
#    21. AI_Agents_vs_Agentic_AI
#    22. AI_Agents_vs_Agentic_AI
#    23. AI_Agents_vs_Agentic_AI
#    24. AI_Agents_vs_Agentic_AI
#    25. AI_Agents_vs_Agentic_AI
#    26. AI_Agents_vs_Agentic_AI
#    27. AI_Agents_vs_Agentic_AI
#    28. AI_Agents_vs_Agentic_AI
#    29. AI_Agents_vs_Agentic_AI
#    30. AI_Agents_vs_Agentic_AI
#    31. AI_Agents_vs_Agentic_AI
#    32. AI_Agents_vs_Agentic_AI
#    33. Emerging_Agent_Architectures
#    34. Emerging_Agent_Architectures
#    35. Emerging_Agent_Architectures
#    36. Emerging_Agent_Architectures
#    37. Emerging_Agent_Architectures
#    38. Emerging_Agent_Architectures
#    39. Emerging_Agent_Architectures
#    40. Emerging_Agent_Architectures
#    41. Emerging_Agent_Architectures
#    42. Emerging_Agent_Architectures
#    43. Emerging_Agent_Architectures
#    44. Emerging_Agent_Architectures
#    45. Emerging_Agent_Architectures
#    46. LLMReasoning_to_Autonomous_Agents
#    47. LLMReasoning_to_Autonomous_Agents
#    48. LLMReasoning_to_Autonomous_Agents
#    49. LLMReasoning_to_Autonomous_Agents
#    50. LLMReasoning_to_Autonomous_Agents
#    51. LLMReasoning_to_Autonomous_Agents
#    52. LLMReasoning_to_Autonomous_Agents
#    53. LLMReasoning_to_Autonomous_Agents
#    54. LLMReasoning_to_Autonomous_Agents
#    55. LLMReasoning_to_Autonomous_Agents
#    56. LLMReasoning_to_Autonomous_Agents
#    57. LLMReasoning_to_Autonomous_Agents
#    58. LLMReasoning_to_Autonomous_Agents
#    59. LLMReasoning_to_Autonomous_Agents
#    60. LLMReasoning_to_Autonomous_Agents
#    61. LLMReasoning_to_Autonomous_Agents
#    62. LLMReasoning_to_Autonomous_Agents
#    63. LLMReasoning_to_Autonomous_Agents
#    64. LLMReasoning_to_Autonomous_Agents
#    65. LLMReasoning_to_Autonomous_Agents
#    66. LLMReasoning_to_Autonomous_Agents
#    67. LLMReasoning_to_Autonomous_Agents
#    68. LLMReasoning_to_Autonomous_Agents
#    69. LLMReasoning_to_Autonomous_Agents
#    70. LLMReasoning_to_Autonomous_Agents
#    71. LLMReasoning_to_Autonomous_Agents
#    72. LLMReasoning_to_Autonomous_Agents
#    73. LLMReasoning_to_Autonomous_Agents
#    74. LLMReasoning_to_Autonomous_Agents
#    75. LLMReasoning_to_Autonomous_Agents
#    76. LLMReasoning_to_Autonomous_Agents
#    77. LLMReasoning_to_Autonomous_Agents
#    78. LLMReasoning_to_Autonomous_Agents
#    79. LLMReasoning_to_Autonomous_Agents
#    80. LLMReasoning_to_Autonomous_Agents
#    81. LLMReasoning_to_Autonomous_Agents
#    82. LLMReasoning_to_Autonomous_Agents
#    83. LLMReasoning_to_Autonomous_Agents
#    84. LLMReasoning_to_Autonomous_Agents
#    85. LLMReasoning_to_Autonomous_Agents
#    86. LLMReasoning_to_Autonomous_Agents
#    87. LLMReasoning_to_Autonomous_Agents
#    88. LLMReasoning_to_Autonomous_Agents
#    89. LLMReasoning_to_Autonomous_Agents
#    90. Rise_and_Potential_LLM_Agents
#    91. Rise_and_Potential_LLM_Agents
#    92. Rise_and_Potential_LLM_Agents
#    93. Rise_and_Potential_LLM_Agents
#    94. Rise_and_Potential_LLM_Agents
#    95. Rise_and_Potential_LLM_Agents
#    96. Rise_and_Potential_LLM_Agents
#    97. Rise_and_Potential_LLM_Agents
#    98. Rise_and_Potential_LLM_Agents
#    99. Rise_and_Potential_LLM_Agents
#    100. Rise_and_Potential_LLM_Agents
#    101. Rise_and_Potential_LLM_Agents
#    102. Rise_and_Potential_LLM_Agents
#    103. Rise_and_Potential_LLM_Agents
#    104. Rise_and_Potential_LLM_Agents
#    105. Rise_and_Potential_LLM_Agents
#    106. Rise_and_Potential_LLM_Agents
#    107. Rise_and_Potential_LLM_Agents
#    108. Rise_and_Potential_LLM_Agents
#    109. Rise_and_Potential_LLM_Agents
#    110. Rise_and_Potential_LLM_Agents
#    111. Rise_and_Potential_LLM_Agents
#    112. Rise_and_Potential_LLM_Agents
#    113. Rise_and_Potential_LLM_Agents
#    114. Rise_and_Potential_LLM_Agents
#    115. Rise_and_Potential_LLM_Agents
#    116. Rise_and_Potential_LLM_Agents
#    117. Rise_and_Potential_LLM_Agents
#    118. Rise_and_Potential_LLM_Agents
#    119. Rise_and_Potential_LLM_Agents
#    120. Rise_and_Potential_LLM_Agents
#    121. Rise_and_Potential_LLM_Agents
#    122. Rise_and_Potential_LLM_Agents
#    123. Rise_and_Potential_LLM_Agents
#    124. Rise_and_Potential_LLM_Agents
#    125. Rise_and_Potential_LLM_Agents
#    126. Rise_and_Potential_LLM_Agents
#    127. Rise_and_Potential_LLM_Agents
#    128. Rise_and_Potential_LLM_Agents
#    129. Rise_and_Potential_LLM_Agents
#    130. Rise_and_Potential_LLM_Agents
#    131. Rise_and_Potential_LLM_Agents
#    132. Rise_and_Potential_LLM_Agents
#    133. Rise_and_Potential_LLM_Agents
#    134. Rise_and_Potential_LLM_Agents
#    135. Rise_and_Potential_LLM_Agents
#    136. Rise_and_Potential_LLM_Agents
#    137. Rise_and_Potential_LLM_Agents
#    138. Rise_and_Potential_LLM_Agents
#    139. Rise_and_Potential_LLM_Agents
#    140. Rise_and_Potential_LLM_Agents
#    141. Rise_and_Potential_LLM_Agents
#    142. Rise_and_Potential_LLM_Agents
#    143. Rise_and_Potential_LLM_Agents
#    144. Rise_and_Potential_LLM_Agents
#    145. Rise_and_Potential_LLM_Agents
#    146. Rise_and_Potential_LLM_Agents
#    147. Rise_and_Potential_LLM_Agents
#    148. Rise_and_Potential_LLM_Agents
#    149. Rise_and_Potential_LLM_Agents
#    150. Rise_and_Potential_LLM_Agents
#    151. Rise_and_Potential_LLM_Agents
#    152. Rise_and_Potential_LLM_Agents
#    153. Rise_and_Potential_LLM_Agents
#    154. Rise_and_Potential_LLM_Agents
#    155. Rise_and_Potential_LLM_Agents
#    156. Rise_and_Potential_LLM_Agents
#    157. Rise_and_Potential_LLM_Agents
#    158. Rise_and_Potential_LLM_Agents
#    159. Rise_and_Potential_LLM_Agents
#    160. Rise_and_Potential_LLM_Agents
#    161. Rise_and_Potential_LLM_Agents
#    162. Rise_and_Potential_LLM_Agents
#    163. Rise_and_Potential_LLM_Agents
#    164. Rise_and_Potential_LLM_Agents
#    165. Rise_and_Potential_LLM_Agents
#    166. Rise_and_Potential_LLM_Agents
#    167. Rise_and_Potential_LLM_Agents
#    168. Rise_and_Potential_LLM_Agents
#    169. Rise_and_Potential_LLM_Agents
#    170. Rise_and_Potential_LLM_Agents
#    171. Rise_and_Potential_LLM_Agents
#    172. Rise_and_Potential_LLM_Agents
#    173. Rise_and_Potential_LLM_Agents
#    174. Rise_and_Potential_LLM_Agents
#    175. Rise_and_Potential_LLM_Agents
#    176. survey_of_self_evolving_agents
#    177. survey_of_self_evolving_agents
#    178. survey_of_self_evolving_agents
#    179. survey_of_self_evolving_agents
#    180. survey_of_self_evolving_agents
#    181. survey_of_self_evolving_agents
#    182. survey_of_self_evolving_agents
#    183. survey_of_self_evolving_agents
#    184. survey_of_self_evolving_agents
#    185. survey_of_self_evolving_agents
#    186. survey_of_self_evolving_agents
#    187. survey_of_self_evolving_agents
#    188. survey_of_self_evolving_agents
#    189. survey_of_self_evolving_agents
#    190. survey_of_self_evolving_agents
#    191. survey_of_self_evolving_agents
#    192. survey_of_self_evolving_agents
#    193. survey_of_self_evolving_agents
#    194. survey_of_self_evolving_agents
#    195. survey_of_self_evolving_agents
#    196. survey_of_self_evolving_agents
#    197. survey_of_self_evolving_agents
#    198. survey_of_self_evolving_agents
#    199. survey_of_self_evolving_agents
#    200. survey_of_self_evolving_agents
#    201. survey_of_self_evolving_agents
#    202. survey_of_self_evolving_agents
#    203. survey_of_self_evolving_agents
#    204. survey_of_self_evolving_agents
#    205. survey_of_self_evolving_agents
#    206. survey_of_self_evolving_agents
#    207. survey_of_self_evolving_agents
#    208. survey_of_self_evolving_agents
#    209. survey_of_self_evolving_agents
#    210. survey_of_self_evolving_agents
#    211. survey_of_self_evolving_agents
#    212. survey_of_self_evolving_agents
#    213. survey_of_self_evolving_agents
#    214. survey_of_self_evolving_agents
#    215. survey_of_self_evolving_agents
#    216. survey_of_self_evolving_agents
#    217. survey_of_self_evolving_agents
#    218. survey_of_self_evolving_agents
#    219. survey_of_self_evolving_agents
#    220. survey_of_self_evolving_agents
#    221. survey_of_self_evolving_agents
#    222. survey_of_self_evolving_agents
#    223. survey_of_self_evolving_agents
#    224. survey_of_self_evolving_agents
#    225. survey_of_self_evolving_agents
#    226. survey_of_self_evolving_agents
#    227. survey_of_self_evolving_agents
#    228. survey_of_self_evolving_agents
#    229. survey_of_self_evolving_agents
#
# ✅ RAG System Analysis Complete!

# %% [markdown]
# ## Conclusion
#
# 🎉 **Congratulations!** You have successfully built a complete RAG (Retrieval-Augmented Generation) system for academic papers using LlamaIndex.
#
# ### What we accomplished:
#
# 1. **Environment Setup**: Configured API keys and dependencies
# 2. **Configuration Management**: Loaded system settings from YAML files
# 3. **LlamaIndex Configuration**: Set up embeddings, LLM, and text processing
# 4. **Vector Store**: Created a LanceDB vector database for storing embeddings
# 5. **Document Processing**: Loaded and processed PDF academic papers
# 6. **Vector Indexing**: Created searchable vector embeddings of documents
# 7. **Query Engine**: Set up retrieval and response generation
# 8. **Search Functions**: Implemented semantic search with metadata
# 9. **Paper Analysis**: Created functions for listing and summarizing papers
# 10. **Interactive Queries**: Built an interface for asking custom questions
# 11. **Performance Analytics**: Added system statistics and monitoring
#
# ### Key Features:
#
# - **Semantic Search**: Find relevant content using natural language queries
# - **Source Attribution**: Get detailed citations and references for answers
# - **Metadata Integration**: Access paper titles, authors, and other metadata
# - **Performance Monitoring**: Track search times and system statistics
# - **Flexible Configuration**: Easy to modify models, chunk sizes, and parameters
#
# ### Next Steps:
#
# 1. **Experiment** with different queries to explore your document collection
# 2. **Modify** the `custom_question` variable to ask your own questions
# 3. **Adjust** parameters like `chunk_size`, `similarity_top_k` for different results
# 4. **Add** more papers to the `papers/agents` folder and rebuild the index
# 5. **Enhance** the system with additional features like filtering or ranking
#
# ### Usage Tips:
#
# - Use specific, focused questions for better results
# - Try different phrasings of the same question
# - Check the source information to understand where answers come from
# - Experiment with the `similarity_top_k` parameter to get more or fewer sources
#
# Happy researching! 🔬📚
