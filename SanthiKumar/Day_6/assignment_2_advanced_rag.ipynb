# %% [markdown]
# # Assignment 2: Advanced RAG Techniques
# ## Day 6 Session 2 - Advanced RAG Fundamentals
#
# **OBJECTIVE:** Implement advanced RAG techniques including postprocessors, response synthesizers, and structured outputs.
#
# **LEARNING GOALS:**
# - Understand and implement node postprocessors for filtering and reranking
# - Learn different response synthesis strategies (TreeSummarize, Refine)
# - Create structured outputs using Pydantic models
# - Build advanced retrieval pipelines with multiple processing stages
#
# **DATASET:** Use the same data folder as Assignment 1 (`Day_6/session_2/data/`)
#
# **PREREQUISITES:** Complete Assignment 1 first
#
# **INSTRUCTIONS:**
# 1. Complete each function by replacing the TODO comments with actual implementation
# 2. Run each cell after completing the function to test it
# 3. The answers can be found in the `03_advanced_rag_techniques.ipynb` notebook
# 4. Each technique builds on the previous one

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -r "/content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt"
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (4.13.5)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (2.30.0)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (2.192.0)
# Requirement already satisfied: google-auth in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (2.47.0)
# Requirement already satisfied: google-auth-httplib2 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 5)) (0.3.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (5.50.0)
# Requirement already satisfied: gradio_client in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 7)) (1.14.0)
# Requirement already satisfied: huggingface-hub==0.34.0 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (0.34.0)
# Requirement already satisfied: websockets==15.0.1 in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 9)) (15.0.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (6.17.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (7.34.0)
# Requirement already satisfied: lancedb in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.30.1)
# Requirement already satisfied: llama-index in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.14.16)
# Requirement already satisfied: llama-index-vector-stores-lancedb in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (0.5.0)
# Requirement already satisfied: llama-index-embeddings-huggingface in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (0.7.0)
# Requirement already satisfied: llama-index-llms-huggingface-api in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 16)) (0.7.0)
# Requirement already satisfied: llama-index-embeddings-openai in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 17)) (0.5.2)
# Requirement already satisfied: llama-index-llms-openrouter in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 18)) (0.5.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 20)) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2.2.2)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (2.28.0)
# Requirement already satisfied: openai-whisper in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (20250625)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (2.12.3)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (5.3.0)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 26)) (2026.3.17)
# Requirement already satisfied: spacy in /usr/local/lib/python3.12/dist-packages (from -r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (3.8.11)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (1.4.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 1)) (2.8.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (1.73.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (5.29.6)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 2)) (1.27.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (0.31.2)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from google-api-python-client->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (4.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: aiofiles<25.0,>=22.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (24.1.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (4.12.1)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.135.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.0.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.28.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.1.6)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.11.7)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.0.22)
# Requirement already satisfied: ruff>=0.9.3 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.15.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.52.1)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.13.3)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.24.1)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.42.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (5.7.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (82.0.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (4.9.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (2.1.0)
# Requirement already satisfied: pyarrow>=16 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (18.1.0)
# Requirement already satisfied: lance-namespace>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: llama-index-cli<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.5)
# Requirement already satisfied: llama-index-core<0.15.0,>=0.14.16 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.14.19)
# Requirement already satisfied: llama-index-indices-managed-llama-cloud>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.11.1)
# Requirement already satisfied: llama-index-llms-openai<0.7,>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.6.26)
# Requirement already satisfied: llama-index-readers-file<0.6,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.6)
# Requirement already satisfied: llama-index-readers-llama-parse>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.6.1)
# Requirement already satisfied: pylance in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (3.0.1)
# Requirement already satisfied: tantivy in /usr/local/lib/python3.12/dist-packages (from llama-index-vector-stores-lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 14)) (0.25.1)
# Requirement already satisfied: llama-index-llms-openai-like<0.7,>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-llms-openrouter->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 18)) (0.6.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 19)) (2025.11.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (2025.3)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 22)) (1.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (10.8.0)
# Requirement already satisfied: numba in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.60.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.12.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (2.10.0+cpu)
# Requirement already satisfied: triton>=2 in /usr/local/lib/python3.12/dist-packages (from openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 24)) (0.4.2)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (4.57.6)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from sentence-transformers->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (1.16.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.24.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (3.11)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: pyparsing<4,>=3.1 in /usr/local/lib/python3.12/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.16.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (3.13.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.8.6)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 10)) (5.9.1)
# Requirement already satisfied: lance-namespace-urllib3-client==0.6.1 in /usr/local/lib/python3.12/dist-packages (from lance-namespace>=0.3.2->lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (0.6.1)
# Requirement already satisfied: urllib3<3.0.0,>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lance-namespace-urllib3-client==0.6.1->lance-namespace>=0.3.2->lancedb->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: aiosqlite in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.22.1)
# Requirement already satisfied: banks<3,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.4.1)
# Requirement already satisfied: dataclasses-json in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.3.1)
# Requirement already satisfied: dirtyjson<2,>=1.0.8 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.0.8)
# Requirement already satisfied: filetype<2,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.2.0)
# Requirement already satisfied: llama-index-workflows!=2.9.0,<3,>=2 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.17.1)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (3.6.1)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (4.9.4)
# Requirement already satisfied: sqlalchemy>=1.4.49 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.48)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (9.1.4)
# Requirement already satisfied: tinytag>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.2.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.9.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.1.2)
# Requirement already satisfied: llama-cloud<2,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-indices-managed-llama-cloud>=0.4.0->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.6.0)
# Requirement already satisfied: defusedxml>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.7.1)
# Requirement already satisfied: pypdf<7,>=6.1.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (6.9.2)
# Requirement already satisfied: striprtf<0.0.27,>=0.0.26 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-file<0.6,>=0.5.0->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.0.26)
# Requirement already satisfied: llama-parse>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from llama-index-readers-llama-parse>=0.4.0->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.20)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 11)) (0.6.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 21)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface-hub==0.34.0->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 8)) (3.4.6)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from thinc<8.4.0,>=8.3.4->spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.1.5)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (1.14.0)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (0.7.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.12/dist-packages (from weasel<0.5.0,>=0.4.2->spacy->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 27)) (7.5.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba->openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (0.43.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->sentence-transformers->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 25)) (3.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->huggingface-hub[inference]>=0.19.0->llama-index-embeddings-huggingface->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 15)) (1.23.0)
# Requirement already satisfied: griffe in /usr/local/lib/python3.12/dist-packages (from banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: llama-index-instrumentation>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from llama-index-workflows!=2.9.0,<3,>=2->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=1.4.49->sqlalchemy[asyncio]>=1.4.49->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (3.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->openai-whisper->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect>=0.8.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (1.1.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (3.26.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer<1.0,>=0.12->gradio->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 6)) (0.1.2)
# Requirement already satisfied: griffecli==2.0.2 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: griffelib==2.0.2 in /usr/local/lib/python3.12/dist-packages (from griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (2.0.2)
# Requirement already satisfied: colorama>=0.4 in /usr/local/lib/python3.12/dist-packages (from griffecli==2.0.2->griffe->banks<3,>=2.3.0->llama-index-core<0.15.0,>=0.14.16->llama-index->-r /content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/requirements.txt (line 13)) (0.4.6)

# %%
# Import required libraries for advanced RAG
import os
from pathlib import Path
from typing import Dict, List, Optional, Any
from pydantic import BaseModel, Field

# Core LlamaIndex components
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, StorageContext, Settings
from llama_index.core.query_engine import RetrieverQueryEngine
from llama_index.core.retrievers import VectorIndexRetriever

# Vector store
from llama_index.vector_stores.lancedb import LanceDBVectorStore

# Embeddings and LLM
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.llms.openrouter import OpenRouter

# Advanced RAG components (we'll use these in the assignments)
from llama_index.core.postprocessor import SimilarityPostprocessor
from llama_index.core.response_synthesizers import TreeSummarize, Refine, CompactAndRefine
from llama_index.core.output_parsers import PydanticOutputParser

print("✅ Advanced RAG libraries imported successfully!")
# Out:
# ✅ Advanced RAG libraries imported successfully!

# %%
from google.colab import userdata

api_key = userdata.get('OPENROUTER_API_KEY')

# %%
# Configure Advanced RAG Settings (Using OpenRouter)
def setup_advanced_rag_settings():
    """
    Configure LlamaIndex with optimized settings for advanced RAG.
    Uses local embeddings and OpenRouter for LLM operations.
    """
    # Check for OpenRouter API key
    # if not api_key:
    #     print("⚠️  OPENROUTER_API_KEY not found - LLM operations will be limited")
    #     print("   You can still complete postprocessor and retrieval exercises")
    # else:
    #     print("✅ OPENROUTER_API_KEY found - full advanced RAG functionality available")

    # Configure OpenRouter LLM
    Settings.llm = OpenRouter(
        api_key=api_key,
        model="gpt-4o",
        temperature=0.1  # Lower temperature for more consistent responses
    )

    # Configure local embeddings (no API key required)
    Settings.embed_model = HuggingFaceEmbedding(
        model_name="BAAI/bge-small-en-v1.5",
        trust_remote_code=True
    )

    # Advanced RAG configuration
    Settings.chunk_size = 512  # Smaller chunks for better precision
    Settings.chunk_overlap = 50

    print("✅ Advanced RAG settings configured")
    print("   - Chunk size: 512 (optimized for precision)")
    print("   - Using local embeddings for cost efficiency")
    print("   - OpenRouter LLM ready for response synthesis")

# Setup the configuration
setup_advanced_rag_settings()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/743 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/133M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/366 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# ✅ Advanced RAG settings configured
#    - Chunk size: 512 (optimized for precision)
#    - Using local embeddings for cost efficiency
#    - OpenRouter LLM ready for response synthesis

# %%
# Setup: Create index from Assignment 1 (reuse the basic functionality)
def setup_basic_index(data_folder: str = "/content/drive/MyDrive/Accelerator/practice/ai-accelerator-C5/Day_6/session_2/data", force_rebuild: bool = False):
    """
    Create a basic vector index that we'll enhance with advanced techniques.
    This reuses the concepts from Assignment 1.
    """
    # Create vector store
    vector_store = LanceDBVectorStore(
        uri="./advanced_rag_vectordb",
        table_name="documents"
    )

    # Load documents
    if not Path(data_folder).exists():
        print(f"❌ Data folder not found: {data_folder}")
        return None

    reader = SimpleDirectoryReader(input_dir=data_folder, recursive=True)
    documents = reader.load_data()

    # Create storage context and index
    storage_context = StorageContext.from_defaults(vector_store=vector_store)
    index = VectorStoreIndex.from_documents(
        documents,
        storage_context=storage_context,
        show_progress=True
    )

    print(f"✅ Basic index created with {len(documents)} documents")
    print("   Ready for advanced RAG techniques!")
    return index

# Create the basic index
print("📁 Setting up basic index for advanced RAG...")
index = setup_basic_index()

if index:
    print("🚀 Ready to implement advanced RAG techniques!")
else:
    print("❌ Failed to create index - check data folder path")
# Out:
# WARNING:llama_index.vector_stores.lancedb.base:Table documents doesn't exist yet. Please add some data to create it.
# 📁 Setting up basic index for advanced RAG...
# 100%|████████████████████████████████████████| 139M/139M [00:01<00:00, 110MiB/s]
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# /usr/local/lib/python3.12/dist-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Applying transformations:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/94 [00:00<?, ?it/s]
# ✅ Basic index created with 42 documents
#    Ready for advanced RAG techniques!
# 🚀 Ready to implement advanced RAG techniques!

# %% [markdown]
# ## 1. Node Postprocessors - Similarity Filtering
#
# **Concept:** Postprocessors refine retrieval results after the initial vector search. The `SimilarityPostprocessor` filters out chunks that fall below a relevance threshold.
#
# **Why it matters:** Raw vector search often returns some irrelevant results. Filtering improves precision and response quality.
#
# Complete the function below to create a query engine with similarity filtering.

# %%
from llama_index.core.postprocessor import SimilarityPostprocessor
from llama_index.core.retrievers import VectorIndexRetriever
from llama_index.core.query_engine import RetrieverQueryEngine

def create_query_engine_with_similarity_filter(index, similarity_cutoff: float = 0.3, top_k: int = 10):
    """
    Create a query engine that filters results based on similarity scores.

    TODO: Complete this function to create a query engine with similarity postprocessing.
    HINT: Use index.as_query_engine() with node_postprocessors parameter containing SimilarityPostprocessor

    Args:
        index: Vector index to query
        similarity_cutoff: Minimum similarity score (0.0 to 1.0)
        top_k: Number of initial results to retrieve before filtering

    Returns:
        Query engine with similarity filtering
    """
    # TODO: Create similarity postprocessor with the cutoff threshold
    similarity_processor = SimilarityPostprocessor(similarity_cutoff=similarity_cutoff)

    # Create retriever
    retriever = VectorIndexRetriever(index=index, similarity_top_k=top_k)

    # TODO: Create query engine with similarity filtering
    query_engine = RetrieverQueryEngine(
        retriever=retriever,
        node_postprocessors=[similarity_processor]
    )

    # PLACEHOLDER - Replace with actual implementation
    print(f"TODO: Create query engine with similarity cutoff {similarity_cutoff}")
    return query_engine

# Test the function
if index:
    filtered_engine = create_query_engine_with_similarity_filter(index, similarity_cutoff=0.3)

    if filtered_engine:
        print("✅ Query engine with similarity filtering created")

        # Test query
        test_query = "What are the benefits of AI agents?"
        print(f"\n🔍 Testing query: '{test_query}'")

        # Uncomment when implemented:
        response = filtered_engine.query(test_query)
        print(f"📝 Response: {response}")
        # print("   (Complete the function above to test the response)")
    else:
        print("❌ Failed to create filtered query engine")
else:
    print("❌ No index available - run previous cells first")
# Out:
# <class 'llama_index.core.query_engine.retriever_query_engine.RetrieverQueryEngine'>
# TODO: Create query engine with similarity cutoff 0.3
# ✅ Query engine with similarity filtering created
#
# 🔍 Testing query: 'What are the benefits of AI agents?'
# 📝 Response: AI agents offer several benefits, including the ability to comprehend, reason, and operate within their surroundings. By adopting specific personas, they can enhance their effectiveness in different roles and utilize tools to interact with external data sources. This capability enables them to tackle complex problems, make autonomous decisions, and assist in a variety of tasks. The implementation of multiple agent personas can lead to improved performance in tasks compared to traditional methods. Additionally, both single-agent and multi-agent systems can accomplish complex goals, with multi-agent systems providing advantages in collaborative and parallel task scenarios.

# %% [markdown]
# ## 2. Response Synthesizers - TreeSummarize
#
# **Concept:** Response synthesizers control how retrieved information becomes final answers. `TreeSummarize` builds responses hierarchically, ideal for complex analytical questions.
#
# **Why it matters:** Different synthesis strategies work better for different query types. TreeSummarize excels at comprehensive analysis and long-form responses.
#
# Complete the function below to create a query engine with TreeSummarize response synthesis.

# %%
from llama_index.core.response_synthesizers import TreeSummarize

def create_query_engine_with_tree_summarize(index, top_k: int = 5):
    """
    Create a query engine that uses TreeSummarize for comprehensive responses.

    TODO: Complete this function to create a query engine with TreeSummarize synthesis.
    HINT: Create a TreeSummarize instance, then use index.as_query_engine() with response_synthesizer parameter

    Args:
        index: Vector index to query
        top_k: Number of results to retrieve

    Returns:
        Query engine with TreeSummarize synthesis
    """
    # TODO: Create TreeSummarize response synthesizer
    tree_synthesizer = TreeSummarize()

    # TODO: Create query engine with the synthesizer
    query_engine = index.as_query_engine(
        response_synthesizer=tree_synthesizer,
        similarity_top_k=top_k)

    # PLACEHOLDER - Replace with actual implementation
    print(f"TODO: Create query engine with TreeSummarize synthesis")
    return query_engine

# Test the function
if index:
    tree_engine = create_query_engine_with_tree_summarize(index)

    if tree_engine:
        print("✅ Query engine with TreeSummarize created")

        # Test with a complex analytical query
        analytical_query = "Compare the advantages and disadvantages of different AI agent frameworks"
        print(f"\n🔍 Testing analytical query: '{analytical_query}'")

        # Uncomment when implemented:
        response = tree_engine.query(analytical_query)
        print(f"📝 TreeSummarize Response:\n{response}")
        # print("   (Complete the function above to test comprehensive analysis)")
    else:
        print("❌ Failed to create TreeSummarize query engine")
else:
    print("❌ No index available - run previous cells first")
# Out:
# TODO: Create query engine with TreeSummarize synthesis
# ✅ Query engine with TreeSummarize created
#
# 🔍 Testing analytical query: 'Compare the advantages and disadvantages of different AI agent frameworks'
# 📝 TreeSummarize Response:
# Different AI agent frameworks offer various advantages and disadvantages based on their design and intended use cases.
#
# **Advantages:**
#
# 1. **Autonomous Agents:**
#    - **AutoGPT**: Known for its high level of autonomy in task execution, making it suitable for complex, independent tasks.
#    - **BabyAGI**: Offers a simplified approach, which can be beneficial for users seeking ease of use in autonomous AI.
#    - **AgentGPT**: Provides a web-based platform, enhancing accessibility and ease of deployment.
#
# 2. **Tool-Using Agents:**
#    - **LangChain**: Offers a comprehensive framework for large language model (LLM) applications, making it versatile for general use.
#    - **LlamaIndex**: Specializes in document understanding and retrieval-augmented generation (RAG), making it ideal for document Q&A tasks.
#    - **Semantic Kernel**: Focuses on AI orchestration, which can be advantageous for integrating multiple AI tools and services.
#
# 3. **Multi-Agent Systems:**
#    - **CrewAI**: Facilitates team collaboration, which is beneficial for tasks requiring coordinated efforts.
#    - **MetaGPT**: Supports multi-agent software development, enhancing collaborative coding and project management.
#    - **AutoGen**: Provides

# %% [markdown]
# ## 3. Structured Outputs with Pydantic Models
#
# **Concept:** Structured outputs ensure predictable, parseable responses using Pydantic models. This is essential for API endpoints and data pipelines.
#
# **Why it matters:** Instead of free-text responses, you get type-safe, validated data structures that applications can reliably process.
#
# Complete the function below to create a structured output system for extracting research paper information.

# %%
# First, define the Pydantic models for structured outputs
class ResearchPaperInfo(BaseModel):
    """Structured information about a research paper or AI concept."""
    title: str = Field(description="The main title or concept name")
    key_points: List[str] = Field(description="3-5 main points or findings")
    applications: List[str] = Field(description="Practical applications or use cases")
    summary: str = Field(description="Brief 2-3 sentence summary")

# Import the missing component
from llama_index.core.program import LLMTextCompletionProgram
from llama_index.core.output_parsers import PydanticOutputParser

def create_structured_output_program(output_model: BaseModel = ResearchPaperInfo):
    """
    Create a structured output program using Pydantic models.

    TODO: Complete this function to create a structured output program.
    HINT: Use LLMTextCompletionProgram.from_defaults() with PydanticOutputParser and a prompt template

    Args:
        output_model: Pydantic model class for structured output

    Returns:
        LLMTextCompletionProgram that returns structured data
    """


    prompt_template_str=(
      "Extract structured research paper information from the following context:\n"
      "{context}\n\n"
      "Question: {query}\n\n"
      "Provide the research paper summary in the specified JSON format, pretty print structure"
      )

    # TODO: Create output parser with the Pydantic model
    output_parser = LLMTextCompletionProgram.from_defaults(
        output_parser=PydanticOutputParser(output_model),
        prompt_template_str=prompt_template_str,output_cls=output_model,
        verbose=True)

    # TODO: Create the structured output program
    program = output_parser

    # PLACEHOLDER - Replace with actual implementation
    print(f"TODO: Create structured output program with {output_model.__name__}")
    return program

# Test the function
if index:
    structured_program = create_structured_output_program(ResearchPaperInfo)

    if structured_program:
        print("✅ Structured output program created")

        # Test with retrieval and structured extraction
        structure_query = "Tell me about AI agents and their capabilities"
        print(f"\n🔍 Testing structured query: '{structure_query}'")

        # Get context for structured extraction (Uncomment when implemented)
        retriever = VectorIndexRetriever(index=index, similarity_top_k=3)
        nodes = retriever.retrieve(structure_query)
        context = "\n".join([node.text for node in nodes])

        # Uncomment when implemented:
        response = structured_program(context=context, query=structure_query)
        print(f"📊 Structured Response:\n{response}")
        print("   (Complete the function above to get structured JSON output)")

        print("\n💡 Expected output format:")
        print("   - title: String")
        print("   - key_points: List of strings")
        print("   - applications: List of strings")
        print("   - summary: String")
    else:
        print("❌ Failed to create structured output program")
else:
    print("❌ No index available - run previous cells first")
# Out:
# TODO: Create structured output program with ResearchPaperInfo
# ✅ Structured output program created
#
# 🔍 Testing structured query: 'Tell me about AI agents and their capabilities'
# 📊 Structured Response:
# title='The Landscape of Emerging AI Agent Architectures for Reasoning, Planning, and Tool Calling: A Survey' key_points=['AI agent architectures have significantly enhanced the capability of language models in reasoning, planning, and tool execution.', 'Single-agent and multi-agent patterns exhibit strong performance on complex tasks, with specific strategies enhancing their effectiveness.', 'Challenges exist in agent evaluation due to varying benchmarks and the complexity of agent-specific evaluations.', 'There are notable limitations in current AI-driven agents, including issues with reliability and biases inherited from language models.', 'Future research should focus on improving benchmarks, real-world applicability, and mitigating harmful biases in language models.'] applications=['Developing AI agents for complex goal achievement requiring reasoning and planning.', 'Enhancing existing AI systems with robust agent architectures for improved task execution.', 'Designing dynamic teams of agents for collaborative problem-solving in various domains.'] summary='This survey paper examines advancements in AI agent implementations, focusing on their capabilities in reasoning, planning, and tool execution. It highlights current capabilities, limitations, and suggests considerations for future AI agent design developments.'
#    (Complete the function above to get structured JSON output)
#
# 💡 Expected output format:
#    - title: String
#    - key_points: List of strings
#    - applications: List of strings
#    - summary: String

# %% [markdown]
# ## 4. Advanced Pipeline - Combining All Techniques
#
# **Concept:** Combine multiple advanced techniques into a single powerful query engine: similarity filtering + response synthesis + structured output.
#
# **Why it matters:** Production RAG systems often need multiple techniques working together for optimal results.
#
# Complete the function below to create a comprehensive advanced RAG pipeline.

# %%
def create_advanced_rag_pipeline(index, similarity_cutoff: float = 0.3, top_k: int = 10):
    """
    Create a comprehensive advanced RAG pipeline combining multiple techniques.

    TODO: Complete this function to create the ultimate advanced RAG query engine.
    HINT: Combine SimilarityPostprocessor + TreeSummarize using index.as_query_engine()

    Args:
        index: Vector index to query
        similarity_cutoff: Minimum similarity score for filtering
        top_k: Number of initial results to retrieve

    Returns:
        Advanced query engine with filtering and synthesis combined
    """
    # TODO: Create similarity postprocessor
    similarity_processor = SimilarityPostprocessor(similarity_cutoff=similarity_cutoff)

    # TODO: Create TreeSummarize for comprehensive responses
    tree_synthesizer = TreeSummarize()

    retriever = VectorIndexRetriever(index=index, similarity_top_k=top_k)

    # TODO: Create the comprehensive query engine combining both techniques
    # advanced_engine = ?
    advanced_engine = RetrieverQueryEngine(
        retriever=retriever,
        response_synthesizer=tree_synthesizer,
        node_postprocessors=[similarity_processor]
    )


    # PLACEHOLDER - Replace with actual implementation
    print(f"TODO: Create advanced RAG pipeline with all techniques")
    return advanced_engine

# Test the comprehensive pipeline
if index:
    advanced_pipeline = create_advanced_rag_pipeline(index)

    if advanced_pipeline:
        print("✅ Advanced RAG pipeline created successfully!")
        print("   🔧 Similarity filtering: ✅")
        print("   🌳 TreeSummarize synthesis: ✅")

        # Test with complex query
        complex_query = "Analyze the current state and future potential of AI agent technologies"
        print(f"\n🔍 Testing complex query: '{complex_query}'")

        # Uncomment when implemented:
        response = advanced_pipeline.query(complex_query)
        print(f"🚀 Advanced RAG Response:\n{response}")
        print("   (Complete the function above to test the full pipeline)")

        print("\n🎯 This should provide:")
        print("   - Filtered relevant results only")
        print("   - Comprehensive analytical response")
        print("   - Combined postprocessing and synthesis")
    else:
        print("❌ Failed to create advanced RAG pipeline")
else:
    print("❌ No index available - run previous cells first")
# Out:
# TODO: Create advanced RAG pipeline with all techniques
# ✅ Advanced RAG pipeline created successfully!
#    🔧 Similarity filtering: ✅
#    🌳 TreeSummarize synthesis: ✅
#
# 🔍 Testing complex query: 'Analyze the current state and future potential of AI agent technologies'
# 🚀 Advanced RAG Response:
# AI agent technologies are currently in a promising state, with advancements enabling them to achieve complex goals through improved reasoning, planning, and tool execution capabilities. These technologies are being effectively applied across various domains, particularly in finance, where they enhance productivity and risk management. However, there are challenges such as comprehensive agent evaluation, real-world applicability, and mitigating biases in language models.
#
# The future potential of AI agent technologies is significant, with key areas for improvement including the development of standardized benchmarks for evaluation, enhancing reliability, and better integration into existing systems. Multi-agent systems are particularly promising in complex domains due to their collaborative capabilities. In finance, ongoing research is focusing on scalability, real-time performance, regulatory compliance, and integration with legacy systems. Efforts are also being made towards standardization and best practices to ensure reliability and trustworthiness.
#
# As the field progresses, collaboration between academia, industry, and open-source communities will be crucial. AI agent technologies are expected to transition from experimental deployments to production-scale solutions, offering advancements in areas like wealth management and fraud detection. Open-source initiatives and cloud-native platforms are accelerating innovation, although they require careful evaluation for production use.
#    (Complete the function above to test the full pipeline)
#
# 🎯 This should provide:
#    - Filtered relevant results only
#    - Comprehensive analytical response
#    - Combined postprocessing and synthesis

# %% [markdown]
# ## 5. Final Test - Compare Basic vs Advanced RAG
#
# Once you've completed all the functions above, run this cell to compare basic RAG with your advanced techniques.

# %%
# Final comparison: Basic vs Advanced RAG
print("🚀 Advanced RAG Techniques Assignment - Final Test")
print("=" * 60)

# Test queries for comparison
test_queries = [
    "What are the key capabilities of AI agents?",
    "How do you evaluate agent performance metrics?",
    "Explain the benefits and challenges of multimodal AI systems"
]

# Check if all components were created
components_status = {
    "Basic Index": index is not None,
    "Similarity Filter": 'filtered_engine' in locals() and filtered_engine is not None,
    "TreeSummarize": 'tree_engine' in locals() and tree_engine is not None,
    "Structured Output": 'structured_program' in locals() and structured_program is not None,
    "Advanced Pipeline": 'advanced_pipeline' in locals() and advanced_pipeline is not None
}

print("\n📊 Component Status:")
for component, status in components_status.items():
    status_icon = "✅" if status else "❌"
    print(f"   {status_icon} {component}")

# Create basic query engine for comparison
if index:
    print("\n🔍 Creating basic query engine for comparison...")
    basic_engine = index.as_query_engine(similarity_top_k=5)

    print("\n" + "=" * 60)
    print("🆚 COMPARISON: Basic vs Advanced RAG")
    print("=" * 60)

    for i, query in enumerate(test_queries, 1):
        print(f"\n📋 Test Query {i}: '{query}'")
        print("-" * 50)

        # Basic RAG
        print("🔹 Basic RAG:")
        if basic_engine:
            basic_response = basic_engine.query(query)
            print(f"   Response: {str(basic_response)[:200]}...")
            print("   (Standard vector search + simple response)")

        # Advanced RAG (if implemented)
        print("\n🔸 Advanced RAG (Text Response):")
        if components_status["Advanced Pipeline"]:
            advanced_response_obj = advanced_pipeline.query(query)
            print(f"   Response: {advanced_response_obj.response}")
            print("   (Filtered + TreeSummarize text output)")

            print("\n🔸 Advanced RAG (Structured Output - using Pydantic structured_program):")
            if components_status["Structured Output"]:
                # Get context from the advanced pipeline's retrieved nodes
                context_for_structured_output = "\n".join([node.text for node in advanced_response_obj.source_nodes])
                structured_output = structured_program(context=context_for_structured_output, query=query)
                print(f"   Structured Data: {structured_output}")
                print("   (Pydantic model extraction from pipeline context)")
            else:
                print("   Structured output program not available. Complete create_structured_output_program.")
        else:
            print("   Complete the advanced pipeline function to test")

# Final status
print("\n" + "=" * 60)
print("🎯 Assignment Status:")
completed_count = sum(components_status.values())
total_count = len(components_status)

print(f"   Completed: {completed_count}/{total_count} components")

if completed_count == total_count:
    print("\n🎉 Congratulations! You've mastered Advanced RAG Techniques!")
    print("   ✅ Node postprocessors for result filtering")
    print("   ✅ Response synthesizers for better answers")
    print("   ✅ Structured outputs for reliable data")
    print("   ✅ Advanced pipelines combining all techniques")
    print("\n🚀 You're ready for production RAG systems!")
else:
    missing = total_count - completed_count
    print(f"\n📝 Complete {missing} more components to finish the assignment:")
    for component, status in components_status.items():
        if not status:
            print(f"   - {component}")

print("\n💡 Key learnings:")
print("   - Postprocessors improve result relevance and precision")
print("   - Different synthesizers work better for different query types")
print("   - Structured outputs enable reliable system integration")
print("   - Advanced techniques can be combined for production systems")
# Out:
# 🚀 Advanced RAG Techniques Assignment - Final Test
# ============================================================
#
# 📊 Component Status:
#    ✅ Basic Index
#    ✅ Similarity Filter
#    ✅ TreeSummarize
#    ✅ Structured Output
#    ✅ Advanced Pipeline
#
# 🔍 Creating basic query engine for comparison...
#
# ============================================================
# 🆚 COMPARISON: Basic vs Advanced RAG
# ============================================================
#
# 📋 Test Query 1: 'What are the key capabilities of AI agents?'
# --------------------------------------------------
# 🔹 Basic RAG:
#    Response: AI agents require several key capabilities to effectively solve real-world problems. These include the ability to reason and plan, which are essential for interacting with complex environments and mak...
#    (Standard vector search + simple response)
#
# 🔸 Advanced RAG (Text Response):
#    Response: The key capabilities of AI agents include reasoning, planning, and tool calling. Reasoning allows them to make decisions, solve problems, and adapt to new information. Planning involves creating strategies to achieve goals, often using techniques like task decomposition and iterative refinement. Tool calling enables them to interact with external environments by using various tools to gather or manipulate data. Additionally, AI agents can act autonomously, model complex behaviors and interactions, and collaborate within multi-agent systems to solve complex problems and manage risks.
#    (Filtered + TreeSummarize text output)
#
# 🔸 Advanced RAG (Structured Output - using Pydantic structured_program):
#    Structured Data: title='The Landscape of Emerging AI Agent Architectures for Reasoning, Planning, and Tool Calling: A Survey' key_points=['AI agents are designed to extend language model capabilities to solve real-world challenges through reasoning, planning, and tool calling.', 'Single-agent architectures are effective for tasks with a narrowly defined list of tools and well-defined processes.', 'Multi-agent architectures thrive in collaborative environments requiring multiple distinct execution paths.', 'Key elements for successful agent systems include clear leadership, defined planning phases, and dynamic teams with specific skills.', 'Current challenges include comprehensive agent benchmarks, real-world applicability, and mitigating harmful language model biases.'] applications=['Finance: Development of intelligent financial agents for complex problem-solving.', 'Autonomous decision-making in various industries.', 'Enhanced AI systems for reasoning and planning in dynamic environments.'] summary='This survey paper examines advancements in AI agent implementations, focusing on their capabilities in reasoning, planning, and tool execution. It highlights the strengths and limitations of single and multi-agent architectures, offering insights for future AI agent design and development.'
#    (Pydantic model extraction from pipeline context)
#
# 📋 Test Query 2: 'How do you evaluate agent performance metrics?'
# --------------------------------------------------
# 🔹 Basic RAG:
#    Response: Agent performance metrics are evaluated using both objective and subjective measures. Objective metrics include success rate, output similarity to human responses, and overall efficiency. Subjective m...
#    (Standard vector search + simple response)
#
# 🔸 Advanced RAG (Text Response):
#    Response: Evaluating agent performance metrics involves using a combination of objective and subjective measures. Objective metrics include assessing the success rate, output similarity to human responses, and overall efficiency, which help determine the reliability and accuracy of the agent. Subjective measures focus on evaluating the efficiency of tool use, reliability, and robustness of planning, often requiring human expert evaluation. Key performance indicators such as accuracy, efficiency, robustness, explainability, and risk-adjusted return are also used. Additionally, benchmarks like AgentBench and SmartPlay, as well as real-world data benchmarks like WildBench and SWE-bench, provide insights into specific tasks. Regular monitoring and evaluation are recommended to ensure ongoing performance assessment.
#    (Filtered + TreeSummarize text output)
#
# 🔸 Advanced RAG (Structured Output - using Pydantic structured_program):
#    Structured Data: title='Evaluation and Challenges of AI Agent Systems' key_points=['AgentBench and SmartPlay introduce objective evaluation metrics for agent performance.', 'Real-world benchmarks like WildBench and SWE-bench use real-world data for evaluation.', 'Challenges in agent evaluation include bias, data contamination, and static benchmarks.', 'Multi-agent architectures offer opportunities for intelligent division of labor and feedback.', 'RAISE method improves agent memory and context retention over ReAct method.'] applications=['Evaluating AI agents in web browsing, command-line interfaces, and video games.', 'Using benchmarks like WildBench for assessing real-world conversational tasks.', 'Implementing multi-agent systems for financial tasks like portfolio optimization and fraud detection.', 'Developing dynamic benchmarks to address data contamination and static evaluation issues.'] summary='The paper discusses the evaluation of AI agent systems, highlighting benchmarks like AgentBench and WildBench. It addresses challenges such as bias and data contamination in agent evaluation. Multi-agent architectures and methods like RAISE are explored for improving agent performance and memory retention.'
#    (Pydantic model extraction from pipeline context)
#
# 📋 Test Query 3: 'Explain the benefits and challenges of multimodal AI systems'
# --------------------------------------------------
# 🔹 Basic RAG:
#    Response: Multimodal AI systems offer several benefits, including the ability to process and integrate information from multiple sources, such as text, images, and audio, which can lead to more comprehensive un...
#    (Standard vector search + simple response)
#
# 🔸 Advanced RAG (Text Response):
#    Response: Multimodal AI systems offer several benefits, including the ability to process and integrate information from various data sources like text, images, and audio. This capability enhances the system's understanding and decision-making processes, making it more versatile and effective in handling complex tasks. Additionally, these systems can improve user interactions by providing more natural and intuitive interfaces, as well as offering more comprehensive insights by leveraging multiple modalities.
#
# However, there are challenges associated with these systems. Integrating and synchronizing different types of data requires sophisticated algorithms and significant computational resources. Ensuring the reliability and accuracy of the system across all modalities is also challenging, as errors in one modality can impact overall performance. Furthermore, developing comprehensive benchmarks for evaluation and addressing potential biases from diverse data sources are ongoing challenges.
#    (Filtered + TreeSummarize text output)
#
# 🔸 Advanced RAG (Structured Output - using Pydantic structured_program):
#    Structured Data: title='The Landscape of Emerging AI Agent Architectures for Reasoning, Planning, and Tool Calling: A Survey' key_points=['The paper examines recent advancements in AI agent implementations, focusing on reasoning, planning, and tool execution capabilities.', 'It identifies the current capabilities and limitations of existing AI agent implementations.', 'The survey provides overviews of single-agent and multi-agent architectures, highlighting key patterns and divergences in design choices.', 'The paper discusses the importance of effective tool calling and the challenges of agent evaluation.', 'It suggests important considerations for future developments in AI agent design.'] applications=['AI agents for complex goal execution in various domains.', 'Enhancing reasoning and planning capabilities in autonomous systems.', 'Improving tool execution and interaction with external data sources.'] summary='This survey paper explores the advancements in AI agent architectures, focusing on their reasoning, planning, and tool execution capabilities. It provides insights into single-agent and multi-agent systems, identifies current limitations, and suggests future research directions to enhance AI agent design.'
#    (Pydantic model extraction from pipeline context)
#
# ============================================================
# 🎯 Assignment Status:
#    Completed: 5/5 components
#
# 🎉 Congratulations! You've mastered Advanced RAG Techniques!
#    ✅ Node postprocessors for result filtering
#    ✅ Response synthesizers for better answers
#    ✅ Structured outputs for reliable data
#    ✅ Advanced pipelines combining all techniques
#
# 🚀 You're ready for production RAG systems!
#
# 💡 Key learnings:
#    - Postprocessors improve result relevance and precision
#    - Different synthesizers work better for different query types
#    - Structured outputs enable reliable system integration
#    - Advanced techniques can be combined for production systems
